# %%
from create_working_df import merged_rating_beer
import os
import pandas as pd

# %%
path = '../../data/baseData/minimizedData/'

# %%
BA_beer_loc, BA_rating_loc, RB_beer_loc, RB_rating_loc, BA_ratbeer, RB_ratbeer = merged_rating_beer(path)

# %%
RB_ratbeer.head(100)
# Out:
#     Unnamed: 0                    beer_name  beer_id brewery_name  brewery_id  \
# 0            0            33 Export (Gabon)   410549      Sobraga        3198
# 1            1          Castel Beer (Gabon)   105273      Sobraga        3198
# 2            2          Castel Beer (Gabon)   105273      Sobraga        3198
# 3            3          Castel Beer (Gabon)   105273      Sobraga        3198
# 4            4          Castel Beer (Gabon)   105273      Sobraga        3198
# ..         ...                          ...      ...          ...         ...
# 95          95  Boundary A Berliner Vice #2   386909     Boundary       22818
# 96          96  Boundary A Berliner Vice #2   386909     Boundary       22818
# 97          97  Boundary a Berliner Vice #3   364610     Boundary       22818
# 98          98  Boundary a Berliner Vice #3   364610     Boundary       22818
# 99          99  Boundary a Berliner Vice #3   364610     Boundary       22818
#
# ...

# %%
BA_ratbeer[BA_ratbeer['user_location'] == BA_ratbeer['beer_location']].head(300)
# Out:
#        Unnamed: 0                              beer_name  beer_id  \
# 2               2                          Barelegs Brew    19590
# 3               3                          Barelegs Brew    19590
# 4               4                          Barelegs Brew    19590
# 77             77                               Legbiter    19827
# 79             79                               Legbiter    19827
# ...           ...                                    ...      ...
# 11898       11898  Innis And Gunn Original Oak Aged Beer    12719
# 12097       12097  Innis And Gunn Original Oak Aged Beer    12719
# 12228       12228  Innis And Gunn Original Oak Aged Beer    12719
# 12353       12353  Innis And Gunn Original Oak Aged Beer    12719
# 12366       12366  Innis And Gunn Original Oak Aged Beer    12719
#
#                                brewery_name  brewery_id             style  \
# 2      Strangford Lough Brewing Company Ltd       10093  English Pale Ale
# ...

# %%
def get_var_name(var):
    for name, value in globals().items():
        if value is var:
            return name

# %%
def save_csv_with_directory_check(df, file_path):
    directory = os.path.dirname(file_path)
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    df.to_csv(file_path, index=False)
    print(f"CSV saved to {file_path}")

# %%
save_csv_with_directory_check(BA_beer_loc, 'data/baseData/Modified/' + get_var_name(BA_beer_loc) + '.csv')
save_csv_with_directory_check(BA_rating_loc, 'data/baseData/Modified/' + get_var_name(BA_rating_loc) + '.csv')
save_csv_with_directory_check(RB_beer_loc, 'data/baseData/Modified/' + get_var_name(RB_beer_loc) + '.csv')
save_csv_with_directory_check(RB_rating_loc, 'data/baseData/Modified/' + get_var_name(RB_rating_loc) + '.csv')
save_csv_with_directory_check(BA_ratbeer, 'data/baseData/Modified/' + get_var_name(BA_ratbeer) + '.csv')
save_csv_with_directory_check(RB_ratbeer, 'data/baseData/Modified/' + get_var_name(RB_ratbeer) + '.csv')
# Out:
# CSV saved to data/baseData/Modified/BA_beer_loc.csv
# CSV saved to data/baseData/Modified/BA_rating_loc.csv
# CSV saved to data/baseData/Modified/RB_beer_loc.csv
# CSV saved to data/baseData/Modified/RB_rating_loc.csv
# CSV saved to data/baseData/Modified/BA_ratbeer.csv
# CSV saved to data/baseData/Modified/RB_ratbeer.csv

# %%
BA_ratbeer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8393032 entries, 0 to 8393031
# Data columns (total 16 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   beer_name      string
#  2   beer_id        int64
#  3   brewery_name   string
#  4   brewery_id     int64
#  5   style          string
#  6   user_id        string
#  7   appearance     float64
#  8   aroma          float64
#  9   palate         float64
#  10  taste          float64
#  11  overall        float64
#  12  rating         float64
#  13  user_location  string
#  14  avg            float64
#  15  beer_location  string
# dtypes: float64(7), int64(3), string(6)
# memory usage: 1.0 GB

# %%
BA_ratbeer.head()
# Out:
#    Unnamed: 0      beer_name  beer_id  \
# 0           0          Régab   142544
# 1           1  Barelegs Brew    19590
# 2           2  Barelegs Brew    19590
# 3           3  Barelegs Brew    19590
# 4           4  Barelegs Brew    19590
#
#                                 brewery_name  brewery_id             style  \
# 0  Societe des Brasseries du Gabon (SOBRAGA)       37262   Euro Pale Lager
# 1       Strangford Lough Brewing Company Ltd       10093  English Pale Ale
# 2       Strangford Lough Brewing Company Ltd       10093  English Pale Ale
# 3       Strangford Lough Brewing Company Ltd       10093  English Pale Ale
# 4       Strangford Lough Brewing Company Ltd       10093  English Pale Ale
#
#                  user_id  appearance  aroma  palate  taste  overall  rating  \
# 0         nmann08.184925        3.25   2.75    3.25   2.75      3.0    2.88
# 1     stjamesgate.163714        3.00   3.50    3.50   4.00      3.5    3.67
# ...
