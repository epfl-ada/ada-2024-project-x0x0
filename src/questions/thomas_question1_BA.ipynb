# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
from scipy.stats import mannwhitneyu

# %%
#needs changing but US ratings of beers with user_state and beer_state
# Loading of ratings that only contain u
BA_merged = pd.read_csv('../../minimizedData/BA_ratings_small_plus.csv')
US_ratings = BA_merged.dropna(subset=['beer_location','user_location','rating'])
US_ratings = US_ratings[US_ratings['user_location'].str.startswith('United States,')]
US_ratings = US_ratings[US_ratings['beer_location'].str.startswith('United States,')]

US_ratings['user_state'] = US_ratings['user_location'].apply(lambda x: x.split(',')[1].strip())
US_ratings['beer_state'] = US_ratings['beer_location'].apply(lambda x: x.split(',')[1].strip())
US_ratings = US_ratings.drop(['user_location','beer_location'], axis=1)

US_ratings = US_ratings[(US_ratings['user_state'] != 'United States') & (US_ratings['beer_state'] != 'United States')]

US_ratings.head(3)
# Out:
#                 beer_name   beer_id                  brewery_name  brewery_id  \
# 1008809     Kupfer Kolsch  289320.0  Copper State Brewing Company     49595.0
# 1008810  Northwestern Alt  289321.0  Copper State Brewing Company     49595.0
# 1008811    One Cent Wheat  289319.0  Copper State Brewing Company     49595.0
#
#            style       user_id  appearance  aroma  palate  taste  overall  \
# 1008809   Kölsch  n2185.211743        2.50   4.00    4.00   3.75     3.75
# 1008810  Altbier  n2185.211743        3.00   3.75    4.00   3.50     3.50
# 1008811  Witbier  n2185.211743        3.75   3.25    3.75   3.50     3.50
#
#          rating   avg      user_state beer_state
# 1008809    3.76  3.76  North Carolina  Wisconsin
# 1008810    3.58  3.58  North Carolina  Wisconsin
# 1008811    3.48  3.48  North Carolina  Wisconsin

# %%
#csv file containing all the states and their neighbouring states
#empty list for states that have no neighbours (e.g Alazka, Hawaii)
neighbours_df = pd.read_csv('../../additionalData/bordering_states.csv', dtype={'state':'string', 
                                                                          'neighbours': 'string'})
neighbours_df["neighbours"] = neighbours_df["neighbours"].fillna("").apply(lambda x: x.split(";") if x else [])

neighbours_df.head(3)
# Out:
#      state                                        neighbours  nb_neighbours
# 0  Alabama        [Florida, Georgia, Mississippi, Tennessee]              4
# 1   Alaska                                                []              0
# 2  Arizona  [California, Colorado, Nevada, New Mexico, Utah]              5

# %%
def gather_region_ratings(state, US_ratings, neighbours_df):
    # Get the neighbors for the given state
    neighbours = neighbours_df.loc[neighbours_df['state'] == state, 'neighbours'].values[0]
    
    region_states = [state] + neighbours    
    region_ratings = US_ratings[US_ratings['beer_state'].isin(region_states)]

    in_region_ratings = region_ratings[region_ratings['user_state'].isin(region_states)]['rating'].tolist()
    not_in_region_ratings = region_ratings[~region_ratings['user_state'].isin(region_states)]['rating'].tolist()
    
    return in_region_ratings, not_in_region_ratings

# List of all states
states = US_ratings['beer_state'].unique()

# Initialize the combined dictionary
all_ratings = {'region': [], 'rating': [], 'rating_type': []}

# Loop through each state and gather ratings
for state in states:
    # Gather ratings
    in_region, non_region = gather_region_ratings(state, US_ratings, neighbours_df)

    # Region name
    region_name = f"region_{state}"
    
    # Extend the dictionary for In-Region
    all_ratings['region'].extend([region_name] * len(in_region))
    all_ratings['rating'].extend(in_region)
    all_ratings['rating_type'].extend(['In-Region'] * len(in_region))
    
    # Extend the dictionary for Non-Region
    all_ratings['region'].extend([region_name] * len(non_region))
    all_ratings['rating'].extend(non_region)
    all_ratings['rating_type'].extend(['Non-Region'] * len(non_region))

# Convert results to a DataFrame suitable for plotting
ratings_df = pd.DataFrame(all_ratings)

# %%
def gather_region_ratings(state, US_ratings, neighbours_df):
    neighbours = neighbours_df.loc[neighbours_df['state'] == state, 'neighbours'].values[0]
    
    region_states = [state] + neighbours    
    region_ratings = US_ratings[US_ratings['beer_state'].isin(region_states)]

    in_region_ratings = region_ratings[region_ratings['user_state'].isin(region_states)]
    not_in_region_ratings = region_ratings[~region_ratings['user_state'].isin(region_states)]
    
    return in_region_ratings, not_in_region_ratings

states = US_ratings['beer_state'].unique()

all_ratings = {'region': [], 'rating': [], 'rating_type': [], 'user_state': []}

# Loop through each state and gather the ratings
for state in states:
    in_region, non_region = gather_region_ratings(state, US_ratings, neighbours_df)

    region_name = f"region_{state}"
    
    # Add In-Region ratings to the dictionary
    all_ratings['region'].extend([region_name] * len(in_region))
    all_ratings['rating'].extend(in_region['rating'].tolist())
    all_ratings['rating_type'].extend(['In-Region'] * len(in_region))
    all_ratings['user_state'].extend(in_region['user_state'].tolist())
    
    # Add Non-Region ratings to the dictionary
    all_ratings['region'].extend([region_name] * len(non_region))
    all_ratings['rating'].extend(non_region['rating'].tolist())
    all_ratings['rating_type'].extend(['Non-Region'] * len(non_region))
    all_ratings['user_state'].extend(non_region['user_state'].tolist())

ratings_df = pd.DataFrame(all_ratings)

ratings_df.head()
# Out:
#              region  rating rating_type user_state
# 0  region_Wisconsin    4.04   In-Region  Wisconsin
# 1  region_Wisconsin    4.00   In-Region  Wisconsin
# 2  region_Wisconsin    3.75   In-Region  Wisconsin
# 3  region_Wisconsin    3.90   In-Region   Illinois
# 4  region_Wisconsin    3.25   In-Region  Wisconsin

# %%
for state in states:
    neighbours = neighbours_df.loc[neighbours_df['state'] == state, 'neighbours'].values[0]
    region_states = [state] + neighbours    
    region_ratings = US_ratings[US_ratings['beer_state'].isin(region_states)]

    print(state)
    print(region_ratings.head())
# Out:
# Wisconsin
#                       beer_name   beer_id                  brewery_name  \
# 1008809           Kupfer Kolsch  289320.0  Copper State Brewing Company
# 1008810        Northwestern Alt  289321.0  Copper State Brewing Company
# 1008811          One Cent Wheat  289319.0  Copper State Brewing Company
# 1008812  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
# 1008813  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
#
#          brewery_id                style            user_id  appearance  \
# 1008809     49595.0               Kölsch       n2185.211743        2.50
# 1008810     49595.0              Altbier       n2185.211743        3.00
# 1008811     49595.0              Witbier       n2185.211743        3.75
# 1008812     49595.0  American Blonde Ale       n2185.211743        3.25
# 1008813     49595.0  American Blonde Ale  angerhaus.1049226        4.00
#
#          aroma  palate  taste  overall  rating   avg      user_state  \
# 1008809   4.00    4.00   3.75     3.75    3.76  3.76  North Carolina
# 1008810   3.75    4.00   3.50     3.50    3.58  3.58  North Carolina
# 1008811   3.25    3.75   3.50     3.50    3.48  3.48  North Carolina
# 1008812   3.75    3.50   4.25     4.25    4.00  4.02  North Carolina
# 1008813   4.25    3.75   4.00     4.00    4.04  4.02       Wisconsin
#
#         beer_state
# 1008809  Wisconsin
# 1008810  Wisconsin
# 1008811  Wisconsin
# 1008812  Wisconsin
# 1008813  Wisconsin
# Georgia
#         beer_name  beer_id               brewery_name  brewery_id  \
# 1232906   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232907   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232908   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232909   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232910   #'s Ale  39408.0  Red Brick Brewing Company       864.0
#
#                   style                  user_id  appearance  aroma  palate  \
# 1232906  English Bitter      kendellmarie.684215         NaN    NaN     NaN
# 1232907  English Bitter  ultimatelivewire.554870         NaN    NaN     NaN
# 1232908  English Bitter           oldtime.447888         NaN    NaN     NaN
# 1232909  English Bitter         jophish17.117963         NaN    NaN     NaN
# 1232910  English Bitter            exiled.335252         NaN    NaN     NaN
#
#          taste  overall  rating   avg      user_state beer_state
# 1232906    NaN      NaN     3.0  3.68      California    Georgia
# 1232907    NaN      NaN     4.0  3.68  South Carolina    Georgia
# 1232908    NaN      NaN     4.0  3.68         Georgia    Georgia
# 1232909    NaN      NaN     2.5  3.68         Georgia    Georgia
# 1232910    NaN      NaN     4.0  3.68           Texas    Georgia
# Arkansas
#             beer_name   beer_id          brewery_name  brewery_id  \
# 1314627   After Hours  268103.0  Rebel Kettle Brewing     45702.0
# 1314628    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314629    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314630    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314631  Billy Badass  252144.0  Rebel Kettle Brewing     45702.0
#
#                                   style            user_id  appearance  aroma  \
# 1314627                     Smoked Beer  jvgoor3786.992709        3.75   3.75
# 1314628  American Double / Imperial IPA    mychalg9.446307        4.00   4.00
# 1314629  American Double / Imperial IPA  jvgoor3786.992709        4.00   4.00
# 1314630  American Double / Imperial IPA    champ103.156510        3.50   3.50
# 1314631                          Dubbel     socon67.471054        3.50   3.75
#
#          palate  taste  overall  rating   avg user_state beer_state
# 1314627    3.75   3.75     3.75    3.75  3.75   Arkansas   Arkansas
# 1314628    4.00   4.00     3.75    3.95  3.70   Illinois   Arkansas
# 1314629    4.00   4.00     4.00    4.00  3.70   Arkansas   Arkansas
# 1314630    3.25   3.25     3.00    3.28  3.70      Texas   Arkansas
# 1314631    4.00   4.00     4.00    3.91  4.08   New York   Arkansas
# Louisiana
#             beer_name   beer_id          brewery_name  brewery_id  \
# 1314627   After Hours  268103.0  Rebel Kettle Brewing     45702.0
# 1314628    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314629    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314630    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314631  Billy Badass  252144.0  Rebel Kettle Brewing     45702.0
#
#                                   style            user_id  appearance  aroma  \
# 1314627                     Smoked Beer  jvgoor3786.992709        3.75   3.75
# 1314628  American Double / Imperial IPA    mychalg9.446307        4.00   4.00
# 1314629  American Double / Imperial IPA  jvgoor3786.992709        4.00   4.00
# 1314630  American Double / Imperial IPA    champ103.156510        3.50   3.50
# 1314631                          Dubbel     socon67.471054        3.50   3.75
#
#          palate  taste  overall  rating   avg user_state beer_state
# 1314627    3.75   3.75     3.75    3.75  3.75   Arkansas   Arkansas
# 1314628    4.00   4.00     3.75    3.95  3.70   Illinois   Arkansas
# 1314629    4.00   4.00     4.00    4.00  3.70   Arkansas   Arkansas
# 1314630    3.25   3.25     3.00    3.28  3.70      Texas   Arkansas
# 1314631    4.00   4.00     4.00    3.91  4.08   New York   Arkansas
# West Virginia
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# California
#                  beer_name   beer_id            brewery_name  brewery_id  \
# 1356770  Annabelle's Umber  171727.0  Arcana Brewing Company     30407.0
# 1356771   Arcana Brown Ale  171732.0  Arcana Brewing Company     30407.0
# 1356773     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356774     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356775     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
#
#                       style           user_id  appearance  aroma  palate  \
# 1356770  American Brown Ale  lucnifter.738555        4.00   3.50    3.75
# 1356771  American Brown Ale  lucnifter.738555        3.50   4.00    3.50
# 1356773        American IPA  bearman13.641321        4.00   4.00    3.75
# 1356774        American IPA    maceman.756533        4.25   4.25    4.50
# 1356775        American IPA  lucnifter.738555        3.50   3.25    3.75
#
#          taste  overall  rating   avg  user_state  beer_state
# 1356770   3.75     3.75    3.71  3.71  California  California
# 1356771   3.75     3.75    3.77  3.77  California  California
# 1356773   3.75     3.50    3.78  4.04       Texas  California
# 1356774   4.50     4.50    4.43  4.04    Virginia  California
# 1356775   3.50     3.50    3.47  4.04  California  California
# Washington
#                                   beer_name   beer_id       brewery_name  \
# 2743578                                FiFl  134132.0       Beta Brewing
# 2743579                    Hedge Hopper Ale  147035.0       Beta Brewing
# 2743580                               SMOHk  147036.0       Beta Brewing
# 2743581  Barrel Aged Russian Imperial Stout  266143.0  Big Block Brewing
# 2743582                          Double IPA  214928.0  Big Block Brewing
#
#          brewery_id                           style                user_id  \
# 2743578     36278.0          Fruit / Vegetable Beer  sound_explorer.772855
# 2743579     36278.0         American Pale Wheat Ale      donkster46.836463
# 2743580     36278.0                     Smoked Beer      donkster46.836463
# 2743581     40150.0          Russian Imperial Stout        mdaschaf.442890
# 2743582     40150.0  American Double / Imperial IPA        mdaschaf.442890
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 2743578         NaN    NaN     NaN    NaN      NaN    3.50  3.50  Washington
# 2743579         NaN    NaN     NaN    NaN      NaN    3.00  3.00  Washington
# 2743580         NaN    NaN     NaN    NaN      NaN    3.75  3.75  Washington
# 2743581        3.75    3.5     3.5    3.5      3.5    3.52  3.52  Washington
# 2743582        3.75    3.5     3.5    3.5      3.5    3.52  3.76  Washington
#
#          beer_state
# 2743578  Washington
# 2743579  Washington
# 2743580  Washington
# 2743581  Washington
# 2743582  Washington
# New Hampshire
#              beer_name   beer_id         brewery_name  brewery_id  \
# 2754514  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754515  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754516  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754517  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754518  American Pale  232493.0  Redhook Ale Brewery     18134.0
#
#                            style              user_id  appearance  aroma  \
# 2754514  American Pale Ale (APA)   phoodcritic.818506        3.50   3.25
# 2754515  American Pale Ale (APA)        a77cj7.456904        3.50   3.50
# 2754516  American Pale Ale (APA)  jimbrinkruff.361543        4.00   3.50
# 2754517  American Pale Ale (APA)       seanecy.712881        3.25   3.25
# 2754518  American Pale Ale (APA)      robebo44.764450        3.25   3.00
#
#          palate  taste  overall  rating   avg    user_state     beer_state
# 2754514    3.50   3.50     3.50    3.44  3.47      Michigan  New Hampshire
# 2754515    3.50   3.50     3.50    3.50  3.47  South Dakota  New Hampshire
# 2754516    3.75   4.25     4.00    3.96  3.47       Indiana  New Hampshire
# 2754517    2.75   3.25     3.25    3.20  3.47      Virginia  New Hampshire
# 2754518    3.25   3.50     3.25    3.29  3.47      Virginia  New Hampshire
# Massachusetts
#              beer_name   beer_id         brewery_name  brewery_id  \
# 2754514  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754515  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754516  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754517  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754518  American Pale  232493.0  Redhook Ale Brewery     18134.0
#
#                            style              user_id  appearance  aroma  \
# 2754514  American Pale Ale (APA)   phoodcritic.818506        3.50   3.25
# 2754515  American Pale Ale (APA)        a77cj7.456904        3.50   3.50
# 2754516  American Pale Ale (APA)  jimbrinkruff.361543        4.00   3.50
# 2754517  American Pale Ale (APA)       seanecy.712881        3.25   3.25
# 2754518  American Pale Ale (APA)      robebo44.764450        3.25   3.00
#
#          palate  taste  overall  rating   avg    user_state     beer_state
# 2754514    3.50   3.50     3.50    3.44  3.47      Michigan  New Hampshire
# 2754515    3.50   3.50     3.50    3.50  3.47  South Dakota  New Hampshire
# 2754516    3.75   4.25     4.00    3.96  3.47       Indiana  New Hampshire
# 2754517    2.75   3.25     3.25    3.20  3.47      Virginia  New Hampshire
# 2754518    3.25   3.50     3.25    3.29  3.47      Virginia  New Hampshire
# New Jersey
#             beer_name  beer_id                   brewery_name  brewery_id  \
# 3238979  11 Piper Ale  21655.0  Gaslight Brewery & Restaurant      1340.0
# 3238980  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238981  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238982  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238983  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
#
#                            style          user_id  appearance  aroma  palate  \
# 3238979  Belgian Strong Dark Ale    thedeuce.8257        3.50    3.5     3.5
# 3238980   American Adjunct Lager   metter98.95017        3.25    3.5     3.5
# 3238981   American Adjunct Lager     bandi.679319         NaN    NaN     NaN
# 3238982   American Adjunct Lager  mikerems.435990         NaN    NaN     NaN
# 3238983   American Adjunct Lager  nerofiddled.526        4.00    3.0     3.5
#
#          taste  overall  rating   avg    user_state  beer_state
# 3238979    3.0     3.50    3.30  3.30      New York  New Jersey
# 3238980    3.5     3.75    3.54  3.54      New York  New Jersey
# 3238981    NaN      NaN    3.75  3.54    New Jersey  New Jersey
# 3238982    NaN      NaN    3.50  3.54    New Jersey  New Jersey
# 3238983    3.5     4.00    3.51  3.54  Pennsylvania  New Jersey
# New York
#             beer_name   beer_id              brewery_name  brewery_id  \
# 2838776  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838777  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838778  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838779  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838780  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
#
#                        style            user_id  appearance  aroma  palate  \
# 2838776  American Pale Lager      brewme.785748        3.75   3.75    3.75
# 2838777  American Pale Lager       i3eer.895869        3.75   4.25    3.75
# 2838778  American Pale Lager  ddorsi924.1186725        3.50   3.50    3.00
# 2838779  American Pale Lager      jhfinn.804963        3.25   3.25    3.25
# 2838780  American Pale Lager     acurtis.508168        3.75   3.25    3.25
#
#          taste  overall  rating   avg     user_state     beer_state
# 2838776   3.75     3.75    3.75  3.85  Massachusetts  Massachusetts
# 2838777   4.00     4.00    4.02  3.85  Massachusetts  Massachusetts
# 2838778   3.25     3.25    3.30  3.85  Massachusetts  Massachusetts
# 2838779   3.25     3.25    3.25  3.85       New York  Massachusetts
# 2838780   3.00     3.25    3.18  3.85     New Jersey  Massachusetts
# Colorado
#                       beer_name   beer_id             brewery_name  \
# 3736403  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736404  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736405  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736406  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736407  American India Red Ale  117766.0  Black Shirt Brewing Co.
#
#          brewery_id                     style                 user_id  \
# 3736403     30876.0  American Amber / Red Ale      kmanjohnson.437141
# 3736404     30876.0  American Amber / Red Ale      evanwoertz.1142757
# 3736405     30876.0  American Amber / Red Ale     spaceman_jer.934240
# 3736406     30876.0  American Amber / Red Ale        bwjunkie.1076487
# 3736407     30876.0  American Amber / Red Ale  leeryleprechaun.560187
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 3736403        4.00   3.50    3.50    3.5     3.50    3.53  2.72  California
# 3736404        4.75   4.75    4.75    4.5     4.50    4.60  2.72    Colorado
# 3736405        3.25   3.75    4.00    4.0     4.00    3.90  2.72    Colorado
# 3736406        3.50   4.00    3.25    2.5     3.00    3.10  2.72    Colorado
# 3736407        3.75   3.50    3.25    3.5     3.25    3.44  2.72    Colorado
#
#         beer_state
# 3736403   Colorado
# 3736404   Colorado
# 3736405   Colorado
# 3736406   Colorado
# 3736407   Colorado
# Missouri
#             beer_name   beer_id          brewery_name  brewery_id  \
# 1314627   After Hours  268103.0  Rebel Kettle Brewing     45702.0
# 1314628    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314629    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314630    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314631  Billy Badass  252144.0  Rebel Kettle Brewing     45702.0
#
#                                   style            user_id  appearance  aroma  \
# 1314627                     Smoked Beer  jvgoor3786.992709        3.75   3.75
# 1314628  American Double / Imperial IPA    mychalg9.446307        4.00   4.00
# 1314629  American Double / Imperial IPA  jvgoor3786.992709        4.00   4.00
# 1314630  American Double / Imperial IPA    champ103.156510        3.50   3.50
# 1314631                          Dubbel     socon67.471054        3.50   3.75
#
#          palate  taste  overall  rating   avg user_state beer_state
# 1314627    3.75   3.75     3.75    3.75  3.75   Arkansas   Arkansas
# 1314628    4.00   4.00     3.75    3.95  3.70   Illinois   Arkansas
# 1314629    4.00   4.00     4.00    4.00  3.70   Arkansas   Arkansas
# 1314630    3.25   3.25     3.00    3.28  3.70      Texas   Arkansas
# 1314631    4.00   4.00     4.00    3.91  4.08   New York   Arkansas
# Utah
#                       beer_name   beer_id             brewery_name  \
# 3736403  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736404  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736405  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736406  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736407  American India Red Ale  117766.0  Black Shirt Brewing Co.
#
#          brewery_id                     style                 user_id  \
# 3736403     30876.0  American Amber / Red Ale      kmanjohnson.437141
# 3736404     30876.0  American Amber / Red Ale      evanwoertz.1142757
# 3736405     30876.0  American Amber / Red Ale     spaceman_jer.934240
# 3736406     30876.0  American Amber / Red Ale        bwjunkie.1076487
# 3736407     30876.0  American Amber / Red Ale  leeryleprechaun.560187
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 3736403        4.00   3.50    3.50    3.5     3.50    3.53  2.72  California
# 3736404        4.75   4.75    4.75    4.5     4.50    4.60  2.72    Colorado
# 3736405        3.25   3.75    4.00    4.0     4.00    3.90  2.72    Colorado
# 3736406        3.50   4.00    3.25    2.5     3.00    3.10  2.72    Colorado
# 3736407        3.75   3.50    3.25    3.5     3.25    3.44  2.72    Colorado
#
#         beer_state
# 3736403   Colorado
# 3736404   Colorado
# 3736405   Colorado
# 3736406   Colorado
# 3736407   Colorado
# Maryland
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# Arizona
#                  beer_name   beer_id            brewery_name  brewery_id  \
# 1356770  Annabelle's Umber  171727.0  Arcana Brewing Company     30407.0
# 1356771   Arcana Brown Ale  171732.0  Arcana Brewing Company     30407.0
# 1356773     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356774     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356775     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
#
#                       style           user_id  appearance  aroma  palate  \
# 1356770  American Brown Ale  lucnifter.738555        4.00   3.50    3.75
# 1356771  American Brown Ale  lucnifter.738555        3.50   4.00    3.50
# 1356773        American IPA  bearman13.641321        4.00   4.00    3.75
# 1356774        American IPA    maceman.756533        4.25   4.25    4.50
# 1356775        American IPA  lucnifter.738555        3.50   3.25    3.75
#
#          taste  overall  rating   avg  user_state  beer_state
# 1356770   3.75     3.75    3.71  3.71  California  California
# 1356771   3.75     3.75    3.77  3.77  California  California
# 1356773   3.75     3.50    3.78  4.04       Texas  California
# 1356774   4.50     4.50    4.43  4.04    Virginia  California
# 1356775   3.50     3.50    3.47  4.04  California  California
# Pennsylvania
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# Indiana
#                      beer_name   beer_id     brewery_name  brewery_id  \
# 4774826          !RyeConChile!  189808.0  Deviate Brewing     42205.0
# 4774827          !RyeConChile!  189808.0  Deviate Brewing     42205.0
# 4774828          !RyeConChile!  189808.0  Deviate Brewing     42205.0
# 4774829  Angel's Landing Strip  270695.0  Deviate Brewing     42205.0
# 4774830         Bad Ground Hum  214983.0  Deviate Brewing     42205.0
#
#                                   style                user_id  appearance  \
# 4774826                 American Porter        psmith161.20976        4.25
# 4774827                 American Porter       tsar_riga.753030        4.00
# 4774828                 American Porter        fredmugs.688854        4.00
# 4774829                       Cream Ale  shirtless_mike.487662        4.25
# 4774830  American Double / Imperial IPA     targaflorio.683246        4.00
#
#          aroma  palate  taste  overall  rating   avg user_state beer_state
# 4774826   4.25    4.25   4.25     4.25    4.25  4.06    Indiana    Indiana
# 4774827   4.00    4.25   3.75     4.00    3.93  4.06    Indiana    Indiana
# 4774828   4.00    4.00   4.25     4.00    4.10  4.06    Indiana    Indiana
# 4774829   4.25    4.25   4.25     4.25    4.25  4.25    Indiana    Indiana
# 4774830   4.25    4.00   4.25     4.25    4.21  4.32    Indiana    Indiana
# Montana
#                    beer_name   beer_id       brewery_name  brewery_id  \
# 4915968  Adam West Coast IPA  227531.0  Lone Peak Brewery     16816.0
# 4915969                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915970                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915971      Barrel Aged IPA  227554.0  Lone Peak Brewery     16816.0
# 4915972          Belgian Red  227525.0  Lone Peak Brewery     16816.0
#
#                     style            user_id  appearance  aroma  palate  \
# 4915968      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915969  Belgian Dark Ale      a77cj7.456904        3.75   3.75    3.75
# 4915970  Belgian Dark Ale  socalkicks.663388        3.25   3.25    3.25
# 4915971      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915972  Flanders Red Ale      a77cj7.456904        3.50   3.50    3.50
#
#          taste  overall  rating   avg    user_state beer_state
# 4915968   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915969   3.75     3.75    3.75  3.50  South Dakota    Montana
# 4915970   3.25     3.25    3.25  3.50    California    Montana
# 4915971   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915972   3.50     3.50    3.50  3.50  South Dakota    Montana
# South Dakota
#                    beer_name   beer_id       brewery_name  brewery_id  \
# 4915968  Adam West Coast IPA  227531.0  Lone Peak Brewery     16816.0
# 4915969                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915970                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915971      Barrel Aged IPA  227554.0  Lone Peak Brewery     16816.0
# 4915972          Belgian Red  227525.0  Lone Peak Brewery     16816.0
#
#                     style            user_id  appearance  aroma  palate  \
# 4915968      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915969  Belgian Dark Ale      a77cj7.456904        3.75   3.75    3.75
# 4915970  Belgian Dark Ale  socalkicks.663388        3.25   3.25    3.25
# 4915971      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915972  Flanders Red Ale      a77cj7.456904        3.50   3.50    3.50
#
#          taste  overall  rating   avg    user_state beer_state
# 4915968   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915969   3.75     3.75    3.75  3.50  South Dakota    Montana
# 4915970   3.25     3.25    3.25  3.50    California    Montana
# 4915971   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915972   3.50     3.50    3.50  3.50  South Dakota    Montana
# Tennessee
#         beer_name  beer_id               brewery_name  brewery_id  \
# 1232906   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232907   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232908   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232909   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232910   #'s Ale  39408.0  Red Brick Brewing Company       864.0
#
#                   style                  user_id  appearance  aroma  palate  \
# 1232906  English Bitter      kendellmarie.684215         NaN    NaN     NaN
# 1232907  English Bitter  ultimatelivewire.554870         NaN    NaN     NaN
# 1232908  English Bitter           oldtime.447888         NaN    NaN     NaN
# 1232909  English Bitter         jophish17.117963         NaN    NaN     NaN
# 1232910  English Bitter            exiled.335252         NaN    NaN     NaN
#
#          taste  overall  rating   avg      user_state beer_state
# 1232906    NaN      NaN     3.0  3.68      California    Georgia
# 1232907    NaN      NaN     4.0  3.68  South Carolina    Georgia
# 1232908    NaN      NaN     4.0  3.68         Georgia    Georgia
# 1232909    NaN      NaN     2.5  3.68         Georgia    Georgia
# 1232910    NaN      NaN     4.0  3.68           Texas    Georgia
# Mississippi
#                                                  beer_name   beer_id  \
# 1317991  (2014) Bourbon Barrel Aged Dark Territory Impe...  154501.0
# 1317992  (2014) Bourbon Barrel Aged Dark Territory Impe...  154501.0
# 1317993  (2014) Bourbon Barrel Aged Dark Territory Impe...  154501.0
# 1317994  (2014) Bourbon Barrel Aged Dark Territory Impe...  154501.0
# 1317995  (2014) Bourbon Barrel Aged Dark Territory Impe...  154501.0
#
#                      brewery_name  brewery_id                   style  \
# 1317991  Old Rail Brewing Company     31384.0  Russian Imperial Stout
# 1317992  Old Rail Brewing Company     31384.0  Russian Imperial Stout
# 1317993  Old Rail Brewing Company     31384.0  Russian Imperial Stout
# 1317994  Old Rail Brewing Company     31384.0  Russian Imperial Stout
# 1317995  Old Rail Brewing Company     31384.0  Russian Imperial Stout
#
#                      user_id  appearance  aroma  palate  taste  overall  \
# 1317991      pens1967.758709         4.5   4.25    4.75   4.50     4.50
# 1317992     t_holland.774175         4.5   4.50    4.00   4.75     4.75
# 1317993        kwkdmk.722439         4.0   4.25    4.50   4.25     4.25
# 1317994  marvingarden.782417         5.0   5.00    5.00   5.00     5.00
# 1317995       sandyjh.645261         5.0   5.00    5.00   5.00     5.00
#
#          rating   avg user_state beer_state
# 1317991    4.47  4.67  Louisiana  Louisiana
# 1317992    4.60  4.67  Louisiana  Louisiana
# 1317993    4.26  4.67  Louisiana  Louisiana
# 1317994    5.00  4.67  Louisiana  Louisiana
# 1317995    5.00  4.67   Michigan  Louisiana
# Virginia
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# Alabama
#         beer_name  beer_id               brewery_name  brewery_id  \
# 1232906   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232907   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232908   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232909   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232910   #'s Ale  39408.0  Red Brick Brewing Company       864.0
#
#                   style                  user_id  appearance  aroma  palate  \
# 1232906  English Bitter      kendellmarie.684215         NaN    NaN     NaN
# 1232907  English Bitter  ultimatelivewire.554870         NaN    NaN     NaN
# 1232908  English Bitter           oldtime.447888         NaN    NaN     NaN
# 1232909  English Bitter         jophish17.117963         NaN    NaN     NaN
# 1232910  English Bitter            exiled.335252         NaN    NaN     NaN
#
#          taste  overall  rating   avg      user_state beer_state
# 1232906    NaN      NaN     3.0  3.68      California    Georgia
# 1232907    NaN      NaN     4.0  3.68  South Carolina    Georgia
# 1232908    NaN      NaN     4.0  3.68         Georgia    Georgia
# 1232909    NaN      NaN     2.5  3.68         Georgia    Georgia
# 1232910    NaN      NaN     4.0  3.68           Texas    Georgia
# Delaware
#             beer_name  beer_id                   brewery_name  brewery_id  \
# 3238979  11 Piper Ale  21655.0  Gaslight Brewery & Restaurant      1340.0
# 3238980  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238981  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238982  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
# 3238983  1920's Lager  24410.0  Gaslight Brewery & Restaurant      1340.0
#
#                            style          user_id  appearance  aroma  palate  \
# 3238979  Belgian Strong Dark Ale    thedeuce.8257        3.50    3.5     3.5
# 3238980   American Adjunct Lager   metter98.95017        3.25    3.5     3.5
# 3238981   American Adjunct Lager     bandi.679319         NaN    NaN     NaN
# 3238982   American Adjunct Lager  mikerems.435990         NaN    NaN     NaN
# 3238983   American Adjunct Lager  nerofiddled.526        4.00    3.0     3.5
#
#          taste  overall  rating   avg    user_state  beer_state
# 3238979    3.0     3.50    3.30  3.30      New York  New Jersey
# 3238980    3.5     3.75    3.54  3.54      New York  New Jersey
# 3238981    NaN      NaN    3.75  3.54    New Jersey  New Jersey
# 3238982    NaN      NaN    3.50  3.54    New Jersey  New Jersey
# 3238983    3.5     4.00    3.51  3.54  Pennsylvania  New Jersey
# Iowa
#                       beer_name   beer_id                  brewery_name  \
# 1008809           Kupfer Kolsch  289320.0  Copper State Brewing Company
# 1008810        Northwestern Alt  289321.0  Copper State Brewing Company
# 1008811          One Cent Wheat  289319.0  Copper State Brewing Company
# 1008812  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
# 1008813  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
#
#          brewery_id                style            user_id  appearance  \
# 1008809     49595.0               Kölsch       n2185.211743        2.50
# 1008810     49595.0              Altbier       n2185.211743        3.00
# 1008811     49595.0              Witbier       n2185.211743        3.75
# 1008812     49595.0  American Blonde Ale       n2185.211743        3.25
# 1008813     49595.0  American Blonde Ale  angerhaus.1049226        4.00
#
#          aroma  palate  taste  overall  rating   avg      user_state  \
# 1008809   4.00    4.00   3.75     3.75    3.76  3.76  North Carolina
# 1008810   3.75    4.00   3.50     3.50    3.58  3.58  North Carolina
# 1008811   3.25    3.75   3.50     3.50    3.48  3.48  North Carolina
# 1008812   3.75    3.50   4.25     4.25    4.00  4.02  North Carolina
# 1008813   4.25    3.75   4.00     4.00    4.04  4.02       Wisconsin
#
#         beer_state
# 1008809  Wisconsin
# 1008810  Wisconsin
# 1008811  Wisconsin
# 1008812  Wisconsin
# 1008813  Wisconsin
# Minnesota
#                       beer_name   beer_id                  brewery_name  \
# 1008809           Kupfer Kolsch  289320.0  Copper State Brewing Company
# 1008810        Northwestern Alt  289321.0  Copper State Brewing Company
# 1008811          One Cent Wheat  289319.0  Copper State Brewing Company
# 1008812  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
# 1008813  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
#
#          brewery_id                style            user_id  appearance  \
# 1008809     49595.0               Kölsch       n2185.211743        2.50
# 1008810     49595.0              Altbier       n2185.211743        3.00
# 1008811     49595.0              Witbier       n2185.211743        3.75
# 1008812     49595.0  American Blonde Ale       n2185.211743        3.25
# 1008813     49595.0  American Blonde Ale  angerhaus.1049226        4.00
#
#          aroma  palate  taste  overall  rating   avg      user_state  \
# 1008809   4.00    4.00   3.75     3.75    3.76  3.76  North Carolina
# 1008810   3.75    4.00   3.50     3.50    3.58  3.58  North Carolina
# 1008811   3.25    3.75   3.50     3.50    3.48  3.48  North Carolina
# 1008812   3.75    3.50   4.25     4.25    4.00  4.02  North Carolina
# 1008813   4.25    3.75   4.00     4.00    4.04  4.02       Wisconsin
#
#         beer_state
# 1008809  Wisconsin
# 1008810  Wisconsin
# 1008811  Wisconsin
# 1008812  Wisconsin
# 1008813  Wisconsin
# Kentucky
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# North Carolina
#         beer_name  beer_id               brewery_name  brewery_id  \
# 1232906   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232907   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232908   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232909   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232910   #'s Ale  39408.0  Red Brick Brewing Company       864.0
#
#                   style                  user_id  appearance  aroma  palate  \
# 1232906  English Bitter      kendellmarie.684215         NaN    NaN     NaN
# 1232907  English Bitter  ultimatelivewire.554870         NaN    NaN     NaN
# 1232908  English Bitter           oldtime.447888         NaN    NaN     NaN
# 1232909  English Bitter         jophish17.117963         NaN    NaN     NaN
# 1232910  English Bitter            exiled.335252         NaN    NaN     NaN
#
#          taste  overall  rating   avg      user_state beer_state
# 1232906    NaN      NaN     3.0  3.68      California    Georgia
# 1232907    NaN      NaN     4.0  3.68  South Carolina    Georgia
# 1232908    NaN      NaN     4.0  3.68         Georgia    Georgia
# 1232909    NaN      NaN     2.5  3.68         Georgia    Georgia
# 1232910    NaN      NaN     4.0  3.68           Texas    Georgia
# Nebraska
#                       beer_name   beer_id             brewery_name  \
# 3736403  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736404  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736405  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736406  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736407  American India Red Ale  117766.0  Black Shirt Brewing Co.
#
#          brewery_id                     style                 user_id  \
# 3736403     30876.0  American Amber / Red Ale      kmanjohnson.437141
# 3736404     30876.0  American Amber / Red Ale      evanwoertz.1142757
# 3736405     30876.0  American Amber / Red Ale     spaceman_jer.934240
# 3736406     30876.0  American Amber / Red Ale        bwjunkie.1076487
# 3736407     30876.0  American Amber / Red Ale  leeryleprechaun.560187
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 3736403        4.00   3.50    3.50    3.5     3.50    3.53  2.72  California
# 3736404        4.75   4.75    4.75    4.5     4.50    4.60  2.72    Colorado
# 3736405        3.25   3.75    4.00    4.0     4.00    3.90  2.72    Colorado
# 3736406        3.50   4.00    3.25    2.5     3.00    3.10  2.72    Colorado
# 3736407        3.75   3.50    3.25    3.5     3.25    3.44  2.72    Colorado
#
#         beer_state
# 3736403   Colorado
# 3736404   Colorado
# 3736405   Colorado
# 3736406   Colorado
# 3736407   Colorado
# Wyoming
#                       beer_name   beer_id             brewery_name  \
# 3736403  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736404  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736405  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736406  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736407  American India Red Ale  117766.0  Black Shirt Brewing Co.
#
#          brewery_id                     style                 user_id  \
# 3736403     30876.0  American Amber / Red Ale      kmanjohnson.437141
# 3736404     30876.0  American Amber / Red Ale      evanwoertz.1142757
# 3736405     30876.0  American Amber / Red Ale     spaceman_jer.934240
# 3736406     30876.0  American Amber / Red Ale        bwjunkie.1076487
# 3736407     30876.0  American Amber / Red Ale  leeryleprechaun.560187
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 3736403        4.00   3.50    3.50    3.5     3.50    3.53  2.72  California
# 3736404        4.75   4.75    4.75    4.5     4.50    4.60  2.72    Colorado
# 3736405        3.25   3.75    4.00    4.0     4.00    3.90  2.72    Colorado
# 3736406        3.50   4.00    3.25    2.5     3.00    3.10  2.72    Colorado
# 3736407        3.75   3.50    3.25    3.5     3.25    3.44  2.72    Colorado
#
#         beer_state
# 3736403   Colorado
# 3736404   Colorado
# 3736405   Colorado
# 3736406   Colorado
# 3736407   Colorado
# Vermont
#              beer_name   beer_id         brewery_name  brewery_id  \
# 2754514  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754515  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754516  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754517  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754518  American Pale  232493.0  Redhook Ale Brewery     18134.0
#
#                            style              user_id  appearance  aroma  \
# 2754514  American Pale Ale (APA)   phoodcritic.818506        3.50   3.25
# 2754515  American Pale Ale (APA)        a77cj7.456904        3.50   3.50
# 2754516  American Pale Ale (APA)  jimbrinkruff.361543        4.00   3.50
# 2754517  American Pale Ale (APA)       seanecy.712881        3.25   3.25
# 2754518  American Pale Ale (APA)      robebo44.764450        3.25   3.00
#
#          palate  taste  overall  rating   avg    user_state     beer_state
# 2754514    3.50   3.50     3.50    3.44  3.47      Michigan  New Hampshire
# 2754515    3.50   3.50     3.50    3.50  3.47  South Dakota  New Hampshire
# 2754516    3.75   4.25     4.00    3.96  3.47       Indiana  New Hampshire
# 2754517    2.75   3.25     3.25    3.20  3.47      Virginia  New Hampshire
# 2754518    3.25   3.50     3.25    3.29  3.47      Virginia  New Hampshire
# New Mexico
#                       beer_name   beer_id             brewery_name  \
# 3736403  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736404  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736405  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736406  American India Red Ale  117766.0  Black Shirt Brewing Co.
# 3736407  American India Red Ale  117766.0  Black Shirt Brewing Co.
#
#          brewery_id                     style                 user_id  \
# 3736403     30876.0  American Amber / Red Ale      kmanjohnson.437141
# 3736404     30876.0  American Amber / Red Ale      evanwoertz.1142757
# 3736405     30876.0  American Amber / Red Ale     spaceman_jer.934240
# 3736406     30876.0  American Amber / Red Ale        bwjunkie.1076487
# 3736407     30876.0  American Amber / Red Ale  leeryleprechaun.560187
#
#          appearance  aroma  palate  taste  overall  rating   avg  user_state  \
# 3736403        4.00   3.50    3.50    3.5     3.50    3.53  2.72  California
# 3736404        4.75   4.75    4.75    4.5     4.50    4.60  2.72    Colorado
# 3736405        3.25   3.75    4.00    4.0     4.00    3.90  2.72    Colorado
# 3736406        3.50   4.00    3.25    2.5     3.00    3.10  2.72    Colorado
# 3736407        3.75   3.50    3.25    3.5     3.25    3.44  2.72    Colorado
#
#         beer_state
# 3736403   Colorado
# 3736404   Colorado
# 3736405   Colorado
# 3736406   Colorado
# 3736407   Colorado
# Alaska
#             beer_name   beer_id    brewery_name  brewery_id         style  \
# 5946845  American IPA  102047.0  HooDoo Brewing     30201.0  American IPA
# 5946846  American IPA  102047.0  HooDoo Brewing     30201.0  American IPA
# 5946847  American IPA  102047.0  HooDoo Brewing     30201.0  American IPA
# 5946848  American IPA  102047.0  HooDoo Brewing     30201.0  American IPA
# 5946849  American IPA  102047.0  HooDoo Brewing     30201.0  American IPA
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 5946845  lone_freighter.1202198        3.25   3.75    3.75   3.75     3.75
# 5946846         rspauldi.795807        3.25   3.25    3.25   3.25     3.25
# 5946847         klesniew.725176        3.75   3.75    4.50   3.50     3.25
# 5946848       fellmaniak.904815        4.00   4.25    4.50   4.25     4.25
# 5946849       ducksfan16.299717        3.50   3.50    3.75   3.75     3.50
#
#          rating   avg user_state beer_state
# 5946845    3.72  3.78    Vermont     Alaska
# 5946846    3.25  3.78      Texas     Alaska
# 5946847    3.63  3.78   Virginia     Alaska
# 5946848    4.26  3.78     Alaska     Alaska
# ...
#
#                       style           user_id  appearance  aroma  palate  \
# 1356770  American Brown Ale  lucnifter.738555        4.00   3.50    3.75
# 1356771  American Brown Ale  lucnifter.738555        3.50   4.00    3.50
# 1356773        American IPA  bearman13.641321        4.00   4.00    3.75
# 1356774        American IPA    maceman.756533        4.25   4.25    4.50
# 1356775        American IPA  lucnifter.738555        3.50   3.25    3.75
#
#          taste  overall  rating   avg  user_state  beer_state
# 1356770   3.75     3.75    3.71  3.71  California  California
# 1356771   3.75     3.75    3.77  3.77  California  California
# 1356773   3.75     3.50    3.78  4.04       Texas  California
# 1356774   4.50     4.50    4.43  4.04    Virginia  California
# 1356775   3.50     3.50    3.47  4.04  California  California
# Maine
#              beer_name   beer_id         brewery_name  brewery_id  \
# 2754514  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754515  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754516  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754517  American Pale  232493.0  Redhook Ale Brewery     18134.0
# 2754518  American Pale  232493.0  Redhook Ale Brewery     18134.0
#
#                            style              user_id  appearance  aroma  \
# 2754514  American Pale Ale (APA)   phoodcritic.818506        3.50   3.25
# 2754515  American Pale Ale (APA)        a77cj7.456904        3.50   3.50
# 2754516  American Pale Ale (APA)  jimbrinkruff.361543        4.00   3.50
# 2754517  American Pale Ale (APA)       seanecy.712881        3.25   3.25
# 2754518  American Pale Ale (APA)      robebo44.764450        3.25   3.00
#
#          palate  taste  overall  rating   avg    user_state     beer_state
# 2754514    3.50   3.50     3.50    3.44  3.47      Michigan  New Hampshire
# 2754515    3.50   3.50     3.50    3.50  3.47  South Dakota  New Hampshire
# 2754516    3.75   4.25     4.00    3.96  3.47       Indiana  New Hampshire
# 2754517    2.75   3.25     3.25    3.20  3.47      Virginia  New Hampshire
# 2754518    3.25   3.50     3.25    3.29  3.47      Virginia  New Hampshire
# Ohio
#                                        beer_name   beer_id  \
# 1354606  22nd Street Cerveza Negra Mexican Stout  232199.0
# 1354607                        Aldo's Milk Stout  272250.0
# 1354608                  Black Frost Schwarzbier  160590.0
# 1354609                  Black Frost Schwarzbier  160590.0
# 1354610                      Centre Market Lager  231971.0
#
#                      brewery_name  brewery_id                style  \
# 1354606  Wheeling Brewing Company     38085.0           Chile Beer
# 1354607  Wheeling Brewing Company     38085.0   Milk / Sweet Stout
# 1354608  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354609  Wheeling Brewing Company     38085.0          Schwarzbier
# 1354610  Wheeling Brewing Company     38085.0  American Pale Lager
#
#                         user_id  appearance  aroma  palate  taste  overall  \
# 1354606          wvbeergeek.775        4.00   3.75    3.25   3.25     3.25
# 1354607  somethingclever.719884        4.00   3.00    3.25   2.75     3.25
# 1354608  somethingclever.719884        3.50   3.00    3.00   3.00     3.00
# 1354609          31sam13.870727        3.25   3.50    3.50   3.50     3.50
# 1354610          wvbeergeek.775        3.75   3.25    2.50   2.50     2.50
#
#          rating   avg     user_state     beer_state
# 1354606    3.42  3.42  West Virginia  West Virginia
# 1354607    3.04  3.04           Ohio  West Virginia
# 1354608    3.03  3.12           Ohio  West Virginia
# 1354609    3.49  3.12  New Hampshire  West Virginia
# 1354610    2.76  2.76  West Virginia  West Virginia
# Michigan
#                       beer_name   beer_id                  brewery_name  \
# 1008809           Kupfer Kolsch  289320.0  Copper State Brewing Company
# 1008810        Northwestern Alt  289321.0  Copper State Brewing Company
# 1008811          One Cent Wheat  289319.0  Copper State Brewing Company
# 1008812  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
# 1008813  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
#
#          brewery_id                style            user_id  appearance  \
# 1008809     49595.0               Kölsch       n2185.211743        2.50
# 1008810     49595.0              Altbier       n2185.211743        3.00
# 1008811     49595.0              Witbier       n2185.211743        3.75
# 1008812     49595.0  American Blonde Ale       n2185.211743        3.25
# 1008813     49595.0  American Blonde Ale  angerhaus.1049226        4.00
#
#          aroma  palate  taste  overall  rating   avg      user_state  \
# 1008809   4.00    4.00   3.75     3.75    3.76  3.76  North Carolina
# 1008810   3.75    4.00   3.50     3.50    3.58  3.58  North Carolina
# 1008811   3.25    3.75   3.50     3.50    3.48  3.48  North Carolina
# 1008812   3.75    3.50   4.25     4.25    4.00  4.02  North Carolina
# 1008813   4.25    3.75   4.00     4.00    4.04  4.02       Wisconsin
#
#         beer_state
# 1008809  Wisconsin
# 1008810  Wisconsin
# 1008811  Wisconsin
# 1008812  Wisconsin
# 1008813  Wisconsin
# North Dakota
#                    beer_name   beer_id       brewery_name  brewery_id  \
# 4915968  Adam West Coast IPA  227531.0  Lone Peak Brewery     16816.0
# 4915969                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915970                Babam  197293.0  Lone Peak Brewery     16816.0
# 4915971      Barrel Aged IPA  227554.0  Lone Peak Brewery     16816.0
# 4915972          Belgian Red  227525.0  Lone Peak Brewery     16816.0
#
#                     style            user_id  appearance  aroma  palate  \
# 4915968      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915969  Belgian Dark Ale      a77cj7.456904        3.75   3.75    3.75
# 4915970  Belgian Dark Ale  socalkicks.663388        3.25   3.25    3.25
# 4915971      American IPA      a77cj7.456904        3.75   3.75    3.75
# 4915972  Flanders Red Ale      a77cj7.456904        3.50   3.50    3.50
#
#          taste  overall  rating   avg    user_state beer_state
# 4915968   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915969   3.75     3.75    3.75  3.50  South Dakota    Montana
# 4915970   3.25     3.25    3.25  3.50    California    Montana
# 4915971   3.75     3.75    3.75  3.75  South Dakota    Montana
# 4915972   3.50     3.50    3.50  3.50  South Dakota    Montana
# Nevada
#                  beer_name   beer_id            brewery_name  brewery_id  \
# 1356770  Annabelle's Umber  171727.0  Arcana Brewing Company     30407.0
# 1356771   Arcana Brown Ale  171732.0  Arcana Brewing Company     30407.0
# 1356773     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356774     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
# 1356775     Headbasher IPA  171725.0  Arcana Brewing Company     30407.0
#
#                       style           user_id  appearance  aroma  palate  \
# 1356770  American Brown Ale  lucnifter.738555        4.00   3.50    3.75
# 1356771  American Brown Ale  lucnifter.738555        3.50   4.00    3.50
# 1356773        American IPA  bearman13.641321        4.00   4.00    3.75
# 1356774        American IPA    maceman.756533        4.25   4.25    4.50
# 1356775        American IPA  lucnifter.738555        3.50   3.25    3.75
#
#          taste  overall  rating   avg  user_state  beer_state
# 1356770   3.75     3.75    3.71  3.71  California  California
# 1356771   3.75     3.75    3.77  3.77  California  California
# 1356773   3.75     3.50    3.78  4.04       Texas  California
# 1356774   4.50     4.50    4.43  4.04    Virginia  California
# 1356775   3.50     3.50    3.47  4.04  California  California
# Hawaii
#             beer_name   beer_id             brewery_name  brewery_id  \
# 7263112  808 Pale Ale  171703.0  Waikiki Brewing Company     39753.0
# 7263113  808 Pale Ale  171703.0  Waikiki Brewing Company     39753.0
# 7263115  808 Pale Ale  171703.0  Waikiki Brewing Company     39753.0
# 7263116  808 Pale Ale  171703.0  Waikiki Brewing Company     39753.0
# 7263117  808 Pale Ale  171703.0  Waikiki Brewing Company     39753.0
#
#                            style             user_id  appearance  aroma  \
# 7263112  American Pale Ale (APA)       jebrew.722928        3.25   3.25
# 7263113  American Pale Ale (APA)     cjohns73.541044        3.75   3.75
# 7263115  American Pale Ale (APA)    jschott75.677311        3.50   3.50
# 7263116  American Pale Ale (APA)   natedyk47.1040708        3.75   4.25
# 7263117  American Pale Ale (APA)  uclabrewn84.439438        3.75   3.25
#
#          palate  taste  overall  rating   avg  user_state beer_state
# 7263112    3.25   3.25     3.25    3.25  3.26       Maine     Hawaii
# 7263113    3.75   3.75     3.75    3.75  3.26    Delaware     Hawaii
# 7263115    3.50   3.50     3.50    3.50  3.26    Illinois     Hawaii
# 7263116    4.00   4.25     4.25    4.20  3.26    Michigan     Hawaii
# 7263117    3.50   3.00     3.00    3.16  3.26  California     Hawaii
# Connecticut
#             beer_name   beer_id              brewery_name  brewery_id  \
# 2838776  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838777  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838778  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838779  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
# 2838780  Bald Seagull  206360.0  Cape Ann Brewing Company      8325.0
#
#                        style            user_id  appearance  aroma  palate  \
# 2838776  American Pale Lager      brewme.785748        3.75   3.75    3.75
# 2838777  American Pale Lager       i3eer.895869        3.75   4.25    3.75
# 2838778  American Pale Lager  ddorsi924.1186725        3.50   3.50    3.00
# 2838779  American Pale Lager      jhfinn.804963        3.25   3.25    3.25
# 2838780  American Pale Lager     acurtis.508168        3.75   3.25    3.25
#
#          taste  overall  rating   avg     user_state     beer_state
# 2838776   3.75     3.75    3.75  3.85  Massachusetts  Massachusetts
# 2838777   4.00     4.00    4.02  3.85  Massachusetts  Massachusetts
# 2838778   3.25     3.25    3.30  3.85  Massachusetts  Massachusetts
# 2838779   3.25     3.25    3.25  3.85       New York  Massachusetts
# 2838780   3.00     3.25    3.18  3.85     New Jersey  Massachusetts
# Texas
#             beer_name   beer_id          brewery_name  brewery_id  \
# 1314627   After Hours  268103.0  Rebel Kettle Brewing     45702.0
# 1314628    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314629    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314630    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314631  Billy Badass  252144.0  Rebel Kettle Brewing     45702.0
#
#                                   style            user_id  appearance  aroma  \
# 1314627                     Smoked Beer  jvgoor3786.992709        3.75   3.75
# 1314628  American Double / Imperial IPA    mychalg9.446307        4.00   4.00
# 1314629  American Double / Imperial IPA  jvgoor3786.992709        4.00   4.00
# 1314630  American Double / Imperial IPA    champ103.156510        3.50   3.50
# 1314631                          Dubbel     socon67.471054        3.50   3.75
#
#          palate  taste  overall  rating   avg user_state beer_state
# 1314627    3.75   3.75     3.75    3.75  3.75   Arkansas   Arkansas
# 1314628    4.00   4.00     3.75    3.95  3.70   Illinois   Arkansas
# 1314629    4.00   4.00     4.00    4.00  3.70   Arkansas   Arkansas
# 1314630    3.25   3.25     3.00    3.28  3.70      Texas   Arkansas
# 1314631    4.00   4.00     4.00    3.91  4.08   New York   Arkansas
# Illinois
#                       beer_name   beer_id                  brewery_name  \
# 1008809           Kupfer Kolsch  289320.0  Copper State Brewing Company
# 1008810        Northwestern Alt  289321.0  Copper State Brewing Company
# 1008811          One Cent Wheat  289319.0  Copper State Brewing Company
# 1008812  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
# 1008813  Platinum Coffee Blonde  289324.0  Copper State Brewing Company
#
#          brewery_id                style            user_id  appearance  \
# 1008809     49595.0               Kölsch       n2185.211743        2.50
# 1008810     49595.0              Altbier       n2185.211743        3.00
# 1008811     49595.0              Witbier       n2185.211743        3.75
# 1008812     49595.0  American Blonde Ale       n2185.211743        3.25
# 1008813     49595.0  American Blonde Ale  angerhaus.1049226        4.00
#
#          aroma  palate  taste  overall  rating   avg      user_state  \
# 1008809   4.00    4.00   3.75     3.75    3.76  3.76  North Carolina
# 1008810   3.75    4.00   3.50     3.50    3.58  3.58  North Carolina
# 1008811   3.25    3.75   3.50     3.50    3.48  3.48  North Carolina
# 1008812   3.75    3.50   4.25     4.25    4.00  4.02  North Carolina
# 1008813   4.25    3.75   4.00     4.00    4.04  4.02       Wisconsin
#
#         beer_state
# 1008809  Wisconsin
# 1008810  Wisconsin
# 1008811  Wisconsin
# 1008812  Wisconsin
# 1008813  Wisconsin
# South Carolina
#         beer_name  beer_id               brewery_name  brewery_id  \
# 1232906   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232907   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232908   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232909   #'s Ale  39408.0  Red Brick Brewing Company       864.0
# 1232910   #'s Ale  39408.0  Red Brick Brewing Company       864.0
#
#                   style                  user_id  appearance  aroma  palate  \
# 1232906  English Bitter      kendellmarie.684215         NaN    NaN     NaN
# 1232907  English Bitter  ultimatelivewire.554870         NaN    NaN     NaN
# 1232908  English Bitter           oldtime.447888         NaN    NaN     NaN
# 1232909  English Bitter         jophish17.117963         NaN    NaN     NaN
# 1232910  English Bitter            exiled.335252         NaN    NaN     NaN
#
#          taste  overall  rating   avg      user_state beer_state
# 1232906    NaN      NaN     3.0  3.68      California    Georgia
# 1232907    NaN      NaN     4.0  3.68  South Carolina    Georgia
# 1232908    NaN      NaN     4.0  3.68         Georgia    Georgia
# 1232909    NaN      NaN     2.5  3.68         Georgia    Georgia
# 1232910    NaN      NaN     4.0  3.68           Texas    Georgia
# Oklahoma
#             beer_name   beer_id          brewery_name  brewery_id  \
# 1314627   After Hours  268103.0  Rebel Kettle Brewing     45702.0
# 1314628    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314629    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314630    Alphaholic  233880.0  Rebel Kettle Brewing     45702.0
# 1314631  Billy Badass  252144.0  Rebel Kettle Brewing     45702.0
#
#                                   style            user_id  appearance  aroma  \
# 1314627                     Smoked Beer  jvgoor3786.992709        3.75   3.75
# 1314628  American Double / Imperial IPA    mychalg9.446307        4.00   4.00
# 1314629  American Double / Imperial IPA  jvgoor3786.992709        4.00   4.00
# 1314630  American Double / Imperial IPA    champ103.156510        3.50   3.50
# 1314631                          Dubbel     socon67.471054        3.50   3.75
#
#          palate  taste  overall  rating   avg user_state beer_state
# 1314627    3.75   3.75     3.75    3.75  3.75   Arkansas   Arkansas
# 1314628    4.00   4.00     3.75    3.95  3.70   Illinois   Arkansas
# 1314629    4.00   4.00     4.00    4.00  3.70   Arkansas   Arkansas
# 1314630    3.25   3.25     3.00    3.28  3.70      Texas   Arkansas
# 1314631    4.00   4.00     4.00    3.91  4.08   New York   Arkansas

# %%
rat = ratings_df['rating_type'].unique()
print(rat)
# Out:
# ['In-Region' 'Non-Region']

# %%
ratings_df.head(200)
# Out:
#                region  rating rating_type user_state
# 0    region_Wisconsin    4.04   In-Region  Wisconsin
# 1    region_Wisconsin    4.00   In-Region  Wisconsin
# 2    region_Wisconsin    3.75   In-Region  Wisconsin
# 3    region_Wisconsin    3.90   In-Region   Illinois
# 4    region_Wisconsin    3.25   In-Region  Wisconsin
# ..                ...     ...         ...        ...
# 195  region_Wisconsin    3.50   In-Region  Minnesota
# 196  region_Wisconsin    4.25   In-Region  Wisconsin
# 197  region_Wisconsin    3.75   In-Region  Minnesota
# 198  region_Wisconsin    4.15   In-Region  Minnesota
# 199  region_Wisconsin    3.25   In-Region  Minnesota
#
# [200 rows x 4 columns]

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34586648 entries, 0 to 34586647
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   region       object
#  1   rating       float64
#  2   rating_type  object
#  3   user_state   object
# dtypes: float64(1), object(3)
# memory usage: 1.0+ GB

# %%
ratings_df = ratings_df[ratings_df['rating_type'] == 'In-Region']

ratings_df.head()
# Out:
#              region  rating rating_type user_state
# 0  region_Wisconsin    4.04   In-Region  Wisconsin
# 1  region_Wisconsin    4.00   In-Region  Wisconsin
# 2  region_Wisconsin    3.75   In-Region  Wisconsin
# 3  region_Wisconsin    3.90   In-Region   Illinois
# 4  region_Wisconsin    3.25   In-Region  Wisconsin

# %%
cohen_df = cohen_df.sort_values(by='Cohen_d')
plt.figure(figsize=(12, 8))
sns.barplot(
    x='region',  # Use the 'region' column for the x-axis labels
    y='Cohen_d', 
    data=cohen_df, 
    palette='viridis',
    hue='region'
)
plt.axhline(y=0, color='black', linewidth=1)
plt.axhline(y=0.2, color='#FFA07A', linestyle=':', linewidth=2, label='Small effect (d=0.2)')
plt.axhline(y=-0.2, color='#FFA07A', linestyle=':', linewidth=2)
plt.axhline(y=0.5, color='#FF8C00', linestyle=':', linewidth=2, label='Medium effect (d=0.5)')
plt.axhline(y=-0.5, color='#FF8C00', linestyle=':', linewidth=2)
plt.axhline(y=0.8, color='#CD3700', linestyle=':', linewidth=2, label='Large effect (d=0.8)')
plt.axhline(y=-0.8, color='#CD3700', linestyle=':', linewidth=2)
plt.xlabel('State')
plt.ylabel('Cohen’s D')
plt.title('Cohen’s D for In-State vs Out-of-State Ratings by State (Sorted by Cohen’s D)')
plt.xticks(rotation=90)
plt.legend(title='Effect Size Thresholds', loc='upper right')
plt.tight_layout()
plt.show()
