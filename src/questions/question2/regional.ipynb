# %%
import os
import subprocess
from pathlib import Path

"""
Dynamically find the project root (where .git exists) and set it as the current working directory.
"""
project_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
os.chdir(project_root)

# %%
import pandas as pd
from src.questions.question2.utils.regions_cohenD import regions_cohenD
from src.questions.question2.utils.regions_cohensD_interactive import regions_cohenD_interactive

# %%
US_ratings = pd.read_csv('data/USData/BA_US_states_all.csv')

neighbours_df = pd.read_csv('data/additionalData/bordering_states.csv', dtype={'state': 'string', 'neighbours': 'string'})
neighbours_df["neighbours"] = neighbours_df["neighbours"].fillna("").apply(lambda x: x.split(";") if x else [])

cohen_by_region_df = regions_cohenD(neighbours_df, US_ratings)
# Out:
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/src/questions/question2/utils/regions_cohenD.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohen_by_region_df, x='Center State of each Region', y='Cohen_d', palette='viridis')

# %%
regions_cohenD_interactive(neighbours_df, US_ratings, plot=True)
# Out:
#    Center State of each Region   Cohen_d
# 44                     Vermont  0.146341
# 4                   California  0.089581
# 6                  Connecticut  0.084330
# 20               Massachusetts  0.079248
# 28               New Hampshire  0.070151
# 1                       Alaska  0.063092
# 12                    Illinois  0.061465
# 7                     Delaware  0.051732
# 38                Rhode Island  0.049781
# 13                     Indiana  0.041873
# 32              North Carolina  0.034419
# 22                   Minnesota  0.029033
# 2                      Arizona  0.028340
# 31                    New York  0.019569
# 8                      Florida  0.015646
# 48                   Wisconsin  0.012427
# 34                        Ohio -0.000150
# 5                     Colorado -0.015752
# 36                      Oregon -0.016268
# 29                  New Jersey -0.028483
# 9                      Georgia -0.029593
# 21                    Michigan -0.034182
# 24                    Missouri -0.036495
# 14                        Iowa -0.037341
# 26                    Nebraska -0.040329
# 30                  New Mexico -0.041674
# 19                    Maryland -0.043988
# 45                    Virginia -0.047530
# 18                       Maine -0.050786
# 17                   Louisiana -0.053037
# 16                    Kentucky -0.057025
# 39              South Carolina -0.061106
# 42                       Texas -0.065987
# 46                  Washington -0.066191
# 35                    Oklahoma -0.066824
# 37                Pennsylvania -0.070013
# 10                      Hawaii -0.073885
# 3                     Arkansas -0.078688
# 43                        Utah -0.083528
# 27                      Nevada -0.085780
# 47               West Virginia -0.087910
# 49                     Wyoming -0.119524
# 0                      Alabama -0.120533
# 15                      Kansas -0.122525
# 41                   Tennessee -0.122864
# 33                North Dakota -0.152034
# 25                     Montana -0.158526
# 11                       Idaho -0.210525
# 23                 Mississippi -0.230009
# 40                South Dakota -0.266548

# %%
US_ratings = pd.read_csv('data/USData/RB_US_states_all.csv')

neighbours_df = pd.read_csv('data/additionalData/bordering_states.csv', dtype={'state': 'string', 'neighbours': 'string'})
neighbours_df["neighbours"] = neighbours_df["neighbours"].fillna("").apply(lambda x: x.split(";") if x else [])

cohen_by_region_df = regions_cohenD(neighbours_df, US_ratings)
# Out:
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\question2\utils\regions_cohenD.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohen_by_region_df, x='Center State of each Region', y='Cohen_d', palette='viridis')
