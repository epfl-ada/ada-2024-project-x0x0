# %%
import os
import subprocess
from pathlib import Path

"""
Dynamically find the project root (where .git exists) and set it as the current working directory.
"""
project_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
os.chdir(project_root)

# %%
import pandas as pd
from utils.regions_cohenD import regions_cohenD
from src.questions.question2.utils.regions_cohensD_interactive import regions_cohenD_interactive

# %%
US_ratings = pd.read_csv('data/USData/BA_US_states_all.csv')

neighbours_df = pd.read_csv('data/additionalData/bordering_states.csv', dtype={'state': 'string', 'neighbours': 'string'})
neighbours_df["neighbours"] = neighbours_df["neighbours"].fillna("").apply(lambda x: x.split(";") if x else [])

cohen_by_region_df = regions_cohenD(neighbours_df, US_ratings)
# Out:
# c:\Users\helen\ada-2024-project-x0x0\src\questions\question2\utils\regions_cohenD.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohen_by_region_df, x='Center State of each Region', y='Cohen_d', palette='viridis')

# %%
regions_cohenD_interactive(neighbours_df, US_ratings, plot=True)
# Out:
#    Center State of each Region   Cohen_d
# 28               New Hampshire  0.076932
# 4                   California  0.068791
# 20               Massachusetts  0.067395
# 1                       Alaska  0.063092
# 27                      Nevada  0.061286
# 44                     Vermont  0.060073
# 38                Rhode Island  0.059749
# 6                  Connecticut  0.059749
# 2                      Arizona  0.058747
# 36                      Oregon  0.036800
# 18                       Maine  0.031355
# 14                        Iowa  0.030385
# 21                    Michigan  0.029781
# 48                   Wisconsin  0.028419
# 13                     Indiana  0.022467
# 12                    Illinois  0.018308
# 31                    New York  0.009841
# 16                    Kentucky  0.007034
# 33                North Dakota  0.002971
# 24                    Missouri  0.002199
# 39              South Carolina -0.003274
# 22                   Minnesota -0.009769
# 40                South Dakota -0.011649
# 8                      Florida -0.013167
# 9                      Georgia -0.014737
# 32              North Carolina -0.030121
# 43                        Utah -0.031060
# 29                  New Jersey -0.033804
# 37                Pennsylvania -0.033937
# 5                     Colorado -0.035901
# 45                    Virginia -0.035937
# 0                      Alabama -0.036738
# 41                   Tennessee -0.042799
# 34                        Ohio -0.043057
# 15                      Kansas -0.043471
# 30                  New Mexico -0.045148
# 26                    Nebraska -0.049584
# 49                     Wyoming -0.056614
# 47               West Virginia -0.056668
# 7                     Delaware -0.057938
# 35                    Oklahoma -0.058330
# 46                  Washington -0.060157
# 19                    Maryland -0.064349
# 42                       Texas -0.065884
# 11                       Idaho -0.067379
# 10                      Hawaii -0.073885
# 17                   Louisiana -0.074046
# 3                     Arkansas -0.075343
# 23                 Mississippi -0.120128
# 25                     Montana -0.189563

# %%
US_ratings = pd.read_csv('../../../USData/RB_US_states_all.csv')

neighbours_df = pd.read_csv('../../../additionalData/bordering_states.csv', dtype={'state': 'string', 'neighbours': 'string'})
neighbours_df["neighbours"] = neighbours_df["neighbours"].fillna("").apply(lambda x: x.split(";") if x else [])

cohen_by_region_df = regions_cohenD(neighbours_df, US_ratings)
# Out:
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\question2\utils\regions_cohenD.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohen_by_region_df, x='Center State of each Region', y='Cohen_d', palette='viridis')
