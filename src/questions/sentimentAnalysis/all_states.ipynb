# %%
from NLP_pipeline import sentiment_analysis_results
import pandas as pd

# %%
BA_US_knn_text = pd.read_csv('../../../knnData/BA_US_knn_text.csv')

# %%
df_reduced = BA_US_knn_text[['text','user_state','beer_state']]
df_reduced
# Out:
#                                                       text      user_state  \
# 0                                                      NaN  North Carolina
# 1                                                      NaN  North Carolina
# 2                                                      NaN  North Carolina
# 3                                                      NaN  North Carolina
# 4                                                      NaN       Wisconsin
# ...                                                    ...             ...
# 6331633  It may say APA on this site, but talking to th...    Rhode Island
# 6331634  I'll start off reviewing this beer with the fo...     Connecticut
# 6331635  Served on draft at the pub. Poured a clear yel...        Maryland
# 6331636  Served on tap at the brewpub in a pint glass.A...        Virginia
# 6331637  Dark brown brew served on tap at the brewpub. ...        Maryland
#
#         beer_state
# 0        Wisconsin
# 1        Wisconsin
# ...

# %%
states = df_reduced['user_state'].unique().tolist()
states.sort()
states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
states_minus = states[20:]
states_minus
# Out:
# ['Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
for state in states_minus:
    #i should rereun everything up to massachussets since i changed the pipeline
    print(state)
    sentiment_analysis_results(state, df_reduced)
# Out:
# Massachusetts
# Running...
# (361409, 3)
# Drop NA:  (113256, 3)
# Locals:  (27140, 3)
# Non locals:  (86116, 3)
# Length of text:  17092189
# Picked-up a single as part of a mixed six-pack at Kappy's in Norwell. No canned-on date + last revie
# Need around 171 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Chunk:  6
# Chunk:  7
# Chunk:  8
# Chunk:  9
# Tasty garbage!
# Chunk:  10
# Chunk:  11
# Chunk:  12
# Chunk:  13
# Chunk:  14
# Chunk:  15
# Chunk:  16
# Chunk:  17
# Chunk:  18
# Chunk:  19
# Tasty garbage!
# Chunk:  20
# Chunk:  21
# Chunk:  22
# Chunk:  23
# Chunk:  24
# Chunk:  25
# Chunk:  26
# Chunk:  27
# Chunk:  28
# Chunk:  29
# Tasty garbage!
# Chunk:  30
# Chunk:  31
# Chunk:  32
# Chunk:  33
# Chunk:  34
# Chunk:  35
# Chunk:  36
# Chunk:  37
# Chunk:  38
# Chunk:  39
# Tasty garbage!
# Chunk:  40
# Chunk:  41
# Chunk:  42
# Chunk:  43
# Chunk:  44
# Chunk:  45
# Chunk:  46
# Chunk:  47
# Chunk:  48
# Chunk:  49
# ...
