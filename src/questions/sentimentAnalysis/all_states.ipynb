# %%
import sys
import os

#otherwise our imports get all messed up
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd

from NLP_pipeline import NLP_results_analysis, NLP_pipeline

# %%
BA_US_knn_text = pd.read_csv('../../../knnData/BA_US_knn_text.csv')
NLP_pipeline(BA_US_knn_text, path_BA='BA/')
NLP_results_analysis(BA_US_knn_text)
# Out:
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\NLP_pipeline.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   local_percents = pd.concat([local_percents, df_local], ignore_index=True)
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\NLP_pipeline.py:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nonlocal_percents = pd.concat([nonlocal_percents, df_nonlocal], ignore_index=True)
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\utils\NLP_chi_test.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\utils\NLP_cohenD.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cohen_all_states = pd.concat([df_cohen_all_states, df_cohen], ignore_index=True)

# %%
RB_US_knn_text = pd.read_csv('../../../knnData/RB_US_knn_text.csv')
NLP_pipeline(RB_US_knn_text, path_BA='RB/')
NLP_results_analysis(RB_US_knn_text)
# Out:
# Running... takes 2 hours ish
# Alabama
# Running...
# (15684, 3)
# Drop NA:  (15684, 3)
# Locals:  (1139, 3)
# Non locals:  (14545, 3)
# Length of text:  271695
# Pours gold. Sour cherry and oak aroma and slight grain. Cereal malt and slight Brett funk and fruit.
# Need around 3 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Done
# Length of text:  4066083
# Bottle. It poured black with a smallish beige head and minimal lacing. The aroma was a bit funky at
# Need around 41 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Chunk:  6
# Chunk:  7
# Chunk:  8
# Chunk:  9
# Tasty garbage!
# Chunk:  10
# Chunk:  11
# Chunk:  12
# Chunk:  13
# Chunk:  14
# Chunk:  15
# Chunk:  16
# Chunk:  17
# Chunk:  18
# Chunk:  19
# Tasty garbage!
# Chunk:  20
# Chunk:  21
# Chunk:  22
# Chunk:  23
# Chunk:  24
# Chunk:  25
# Chunk:  26
# Chunk:  27
# Chunk:  28
# Chunk:  29
# Tasty garbage!
# Chunk:  30
# Chunk:  31
# Chunk:  32
# Chunk:  33
# Chunk:  34
# Chunk:  35
# Chunk:  36
# Chunk:  37
# Chunk:  38
# Chunk:  39
# Tasty garbage!
# Chunk:  40
# Done
# Number of positive sentences: 1918
# Number of negative sentences: 519
# Number of neutral sentences: 3367
# Number of positive sentences: 32455
# Number of negative sentences: 8495
# Number of neutral sentences: 39567
#   sentences  count percentage
# 0     total   5804        N/A
# 1  positive   1918  33.046175
# 2  negative    519   8.942109
# 3   neutral   3367  58.011716
#   sentences  count percentage
# 0     total  80517        N/A
# 1  positive  32455  40.308258
# 2  negative   8495  10.550567
# 3   neutral  39567  49.141175
# Saved!
# Alaska
# Running...
# (6636, 3)
# Drop NA:  (6636, 3)
# Locals:  (2115, 3)
# Non locals:  (4521, 3)
# Length of text:  519766
# Draft sampler at anchorage brewpub, dark amber beer, skiff of white foam. Aroma is malt, brown sugar
# Need around 5 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Done
# Length of text:  1032626
# On tap @ Ale Asylum. Amber with an off white head. Lot of smooth caramel bready malt with a firm cit
# Need around 10 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Chunk:  6
# Chunk:  7
# Chunk:  8
# Chunk:  9
# Tasty garbage!
# Chunk:  10
# Done
# Number of positive sentences: 3851
# Number of negative sentences: 736
# Number of neutral sentences: 5397
# Number of positive sentences: 8194
# Number of negative sentences: 1729
# Number of neutral sentences: 9947
#   sentences  count percentage
# 0     total   9984        N/A
# 1  positive   3851  38.571715
# 2  negative    736   7.371795
# 3   neutral   5397   54.05649
#   sentences  count percentage
# 0     total  19870        N/A
# 1  positive   8194  41.238047
# 2  negative   1729    8.70156
# 3   neutral   9947  50.060393
# Saved!
# Arizona
# Running...
# (49839, 3)
# Drop NA:  (49839, 3)
# Locals:  (7785, 3)
# Non locals:  (42054, 3)
# Length of text:  2760863
# Very tasty Belgin style beer. Average ABV. Heavier than Blue Moon. Dessert beer. Sweet. Nice color a
# Need around 28 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Chunk:  6
# Chunk:  7
# Chunk:  8
# Chunk:  9
# Tasty garbage!
# Chunk:  10
# Chunk:  11
# Chunk:  12
# Chunk:  13
# Chunk:  14
# Chunk:  15
# Chunk:  16
# Chunk:  17
# Chunk:  18
# Chunk:  19
# Tasty garbage!
# Chunk:  20
# Chunk:  21
# Chunk:  22
# Chunk:  23
# Chunk:  24
# Chunk:  25
# Chunk:  26
# Chunk:  27
# Done
# Length of text:  14405317
# Dark brown with large frothy tan head, lasting with lace. Aroma is pleasantly roasty, chocolate, per
# Need around 144 chunks
# Tasty garbage!
# Chunk:  0
# Chunk:  1
# Chunk:  2
# Chunk:  3
# Chunk:  4
# Chunk:  5
# Chunk:  6
# Chunk:  7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 RB_US_knn_text = pd.read_csv('../../../knnData/RB_US_knn_text.csv')
# ----> 2 NLP_pipeline(RB_US_knn_text, path_BA='RB/')
#       3 NLP_results_analysis(RB_US_knn_text)
#
# File c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\NLP_pipeline.py:20, in NLP_pipeline(US_ratings, path_BA)
#      18 for state in states:
#      19     print(state)
# ---> 20     _, _ = sentiment_analysis_results(state, df_reduced, path_BA)
#      22 return
#
# File c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\utils\sentimentAnalysis.py:104, in sentiment_analysis_results(state, baseData, path_BA, save_dfs, plots)
#     102 #turning text into spacy objects, this can take a while...
#     103 docs_local = create_nlp_doc(df_local)
# --> 104 docs_nonlocal = create_nlp_doc(df_nonlocal)
#     106 #turning into sentences and analysing postive/negative sentiment
#     107 #use plots = True if you want to see some plots
#     108 local_positive_sent, local_negative_sent, local_compound_sent = sentiment_analysis(docs_local, state)
#
# File c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\utils\prepNLP.py:60, in create_nlp_doc(df)
#      57 print(df_text[0:100])
#      59 docs = []
# ---> 60 for doc in split_text_into_chunks(df_text, nlp, chunk_size=100_000):
#      61     docs.append(doc)
#      63 print("Done")
#
# File c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\sentimentAnalysis\utils\prepNLP.py:35, in split_text_into_chunks(large_text, nlp, chunk_size)
#      32     print('Tasty garbage!')
#      34 chunk = large_text[i:i + chunk_size]
# ---> 35 doc = nlp(chunk)
#      36 print("Chunk: ",i//chunk_size)
#      37 chunk_number += 1
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\language.py:1037, in Language.__call__(self, text, disable, component_cfg)
#    1016 def __call__(
#    1017     self,
#    1018     text: Union[str, Doc],
#    (...)
#    1021     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#    1022 ) -> Doc:
#    1023     """Apply the pipeline to some text. The text can span multiple sentences,
#    1024     and can contain arbitrary whitespace. Alignment into the original string
#    1025     is preserved.
#    (...)
#    1035     DOCS: https://spacy.io/api/language#call
#    1036     """
# -> 1037     doc = self._ensure_doc(text)
#    1038     if component_cfg is None:
#    1039         component_cfg = {}
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\language.py:1128, in Language._ensure_doc(self, doc_like)
#    1126     return doc_like
#    1127 if isinstance(doc_like, str):
# -> 1128     return self.make_doc(doc_like)
#    1129 if isinstance(doc_like, bytes):
#    1130     return Doc(self.vocab).from_bytes(doc_like)
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\language.py:1120, in Language.make_doc(self, text)
#    1116 if len(text) > self.max_length:
#    1117     raise ValueError(
#    1118         Errors.E088.format(length=len(text), max_length=self.max_length)
#    1119     )
# -> 1120 return self.tokenizer(text)
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\tokenizer.pyx:151, in spacy.tokenizer.Tokenizer.__call__()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\tokenizer.pyx:187, in spacy.tokenizer.Tokenizer._tokenize_affixes()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\tokenizer.pyx:391, in spacy.tokenizer.Tokenizer._tokenize()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\tokenizer.pyx:485, in spacy.tokenizer.Tokenizer._attach_tokens()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\vocab.pyx:165, in spacy.vocab.Vocab.get()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\vocab.pyx:202, in spacy.vocab.Vocab._new_lexeme()
#
# File c:\Users\Enzo\anaconda3\envs\ada\Lib\site-packages\spacy\lang\lex_attrs.py:161, in is_digit(string)
#     160 def is_digit(string: str) -> bool:
# --> 161     return string.isdigit()
#
# KeyboardInterrupt:
