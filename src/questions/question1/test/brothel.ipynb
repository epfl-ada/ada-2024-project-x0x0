# %%
import pandas as pd

# %%
import subprocess
from pathlib import Path

# def get_project_root() -> Path:
#     # Use git to find the project's root directory
#     return Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())

# # Find the root directory
# project_root = get_project_root()

# # Create paths relative to the project root
# file_path = project_root / 'data' / 'input.txt'

# # Read the file
# with open(file_path, 'r') as f:
#     content = f.read()

# print("File content:", content)
# print("File path:", file_path)

# %%
import os
import subprocess
from pathlib import Path

def set_working_dir_to_project_root():
    # Use git to get the project root directory
    root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
    os.chdir(root)  # Change the working directory to the project root

# Change working directory
set_working_dir_to_project_root()

# Now you can use relative paths
file_path = Path('data/input.txt')

# Read the file
with open(file_path, 'r') as f:
    content = f.read()

print("File content:", content)
print("File path:", file_path.resolve())
# Out:
# File content: bob is dead
# File path: /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/data/input.txt

# %%
import os
import subprocess
from pathlib import Path

# def set_working_directory_to_project_root():
#     """
#     Dynamically find the project root (where .git exists) and set it as the current working directory.
#     """
#     # Get the project root using git
#     project_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
    
#     # Change the working directory to the project root
#     os.chdir(project_root)

# # Set working directory to project root
# set_working_directory_to_project_root()

# # Now all paths can be written as if you're at the project root
# file_path = Path('data/input.txt')

# # Open and read the file
# with open(file_path, 'r') as f:
#     content = f.read()

# print("File content:", content)
# print("File absolute path:", file_path.resolve())

# %%
import os
import subprocess
from pathlib import Path

def set_working_directory_to_project_root():
    """
    Dynamically find the project root (where .git exists) and set it as the current working directory.
    """
    # Get the project root using git
    project_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
    
    # Change the working directory to the project root
    os.chdir(project_root)

# Set working directory to project root
set_working_directory_to_project_root()

# # Now all paths can be written as if you're at the project root
# file_path = Path('data/input.txt')

# # Open and read the file
# with open(file_path, 'r') as f:
#     content = f.read()

# print("File content:", content)
# print("File absolute path:", file_path.resolve())

# %%
file_path = Path("USData/BA_US_states_all.csv")

# Read file
df = pd.read_csv(file_path)
df
# Out:
#                       beer_name   beer_id  \
# 0                 Kupfer Kolsch  289320.0
# 1              Northwestern Alt  289321.0
# 2                One Cent Wheat  289319.0
# 3        Platinum Coffee Blonde  289324.0
# 4        Platinum Coffee Blonde  289324.0
# ...                         ...       ...
# 6331633      Irvington Pale Ale   19141.0
# 6331634              Kölsch Ale   19139.0
# 6331635              Kölsch Ale   19139.0
# 6331636              Kölsch Ale   19139.0
# 6331637           Nut Brown Ale   19140.0
#
#                                 brewery_name  brewery_id  \
# 0               Copper State Brewing Company     49595.0
# 1               Copper State Brewing Company     49595.0
# 2               Copper State Brewing Company     49595.0
# 3               Copper State Brewing Company     49595.0
# 4               Copper State Brewing Company     49595.0
# ...                                      ...         ...
# ...

# %%
from utils import set_project_root

set_project_root()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils import set_project_root
#       3 set_project_root()
#
# ModuleNotFoundError: No module named 'utils'
