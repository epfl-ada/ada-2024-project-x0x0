# %%
import os
import subprocess
from pathlib import Path

"""
Dynamically find the project root (where .git exists) and set it as the current working directory.
"""
project_root = Path(subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], text=True).strip())
os.chdir(project_root)

# %%
import pandas as pd
from src.questions.styleAnalysis.styles import analyseStyles

# %%
US_ratings = pd.read_csv('data/USData/BA_US_states_all.csv')
print(US_ratings.shape)
unique_styles = US_ratings['style'].unique()
print("Number of unique styles :", len(unique_styles))

state_style_stats = US_ratings.groupby(['user_state', 'style']).agg(average_rating=('rating', 'mean'),nb_ratings=('rating', 'size')).reset_index() #calculating the number of ratings and average ratings per state per beer style
state_style_stats.head(2)
# Out:
# (6331638, 15)
# Number of unique styles : 103
#   user_state                   style  average_rating  nb_ratings
# 0    Alabama                 Altbier        3.579111          90
# 1    Alabama  American Adjunct Lager        2.663220         354

# %%
analyseStyles(state_style_stats)
# Out:
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/src/questions/styleAnalysis/utils/logWeights.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['weight'] = state_style_stats_thresh['average_rating'] * np.log1p(state_style_stats_thresh['nb_ratings'])
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/src/questions/styleAnalysis/utils/logWeights.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['normalized_weight'] = state_style_stats_thresh['weight'] / state_style_stats_thresh.groupby('user_state')['weight'].transform('sum')
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/src/questions/styleAnalysis/utils/logWeights.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['bias_adjusted_weight'] = state_style_stats_thresh['weight'] / state_style_stats_thresh['style'].map(global_popularity_normalized)
# Missing states: {'Puerto Rico', 'District of Columbia'}
# Index(['id', 'name', 'density', 'geometry', 'user_state',
#        'preferred_style_beer', 'average_rating', 'nb_ratings', 'weight',
#        'normalized_weight', 'bias_adjusted_weight'],
#       dtype='object')
# Index(['user_state', 'preferred_style_beer', 'average_rating', 'nb_ratings',
#        'weight', 'normalized_weight', 'bias_adjusted_weight'],
#       dtype='object')
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/xxxetra/ada-2024-project-x0x0/src/questions/styleAnalysis/utils/drawMap.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   us_states['preferred_style_beer'].fillna("No Data", inplace=True)

# %%
RB_US_ratings = pd.read_csv('data/USData/RB_US_states_all.csv')
print(RB_US_ratings.shape)
unique_styles = RB_US_ratings['style'].unique()
print("Number of unique styles :", len(unique_styles))

#calculating the number of ratings and average ratings per state per beer style
state_style_stats = RB_US_ratings.groupby(['user_state', 'style']).agg(average_rating=('rating', 'mean'),nb_ratings=('rating', 'size')).reset_index() 
state_style_stats.head(2)


analyseStyles(state_style_stats)
# Out:
# (2396446, 15)
# Number of unique styles : 83
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\styleAnalysis\utils\logWeights.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['weight'] = state_style_stats_thresh['average_rating'] * np.log1p(state_style_stats_thresh['nb_ratings'])
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\styleAnalysis\utils\logWeights.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['normalized_weight'] = state_style_stats_thresh['weight'] / state_style_stats_thresh.groupby('user_state')['weight'].transform('sum')
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\styleAnalysis\utils\logWeights.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_style_stats_thresh['bias_adjusted_weight'] = state_style_stats_thresh['weight'] / state_style_stats_thresh['style'].map(global_popularity_normalized)
# Missing states: {'Puerto Rico', 'District of Columbia'}
# Index(['id', 'name', 'density', 'geometry', 'user_state',
#        'preferred_style_beer', 'average_rating', 'nb_ratings', 'weight',
#        'normalized_weight', 'bias_adjusted_weight'],
#       dtype='object')
# Index(['user_state', 'preferred_style_beer', 'average_rating', 'nb_ratings',
#        'weight', 'normalized_weight', 'bias_adjusted_weight'],
#       dtype='object')
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\questions\styleAnalysis\utils\drawMap.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   us_states['preferred_style_beer'].fillna("No Data", inplace=True)
