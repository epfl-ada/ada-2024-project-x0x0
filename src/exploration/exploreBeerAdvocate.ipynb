# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Enzo\Desktop\ada-2024-project-x0x0\src\exploration

# %% [markdown]
# ## Looking at BeerAdvocate

# %%
#out of exploration out of src
beers = pd.read_csv('../../baseData/BeerAdvocate/beers.csv')

print(beers.shape)
beers.drop_duplicates(inplace=True)
print(beers.columns)
print(beers.shape)
beers.sample(10)
# Out:
# (280823, 15)
# Index(['beer_id', 'beer_name', 'brewery_id', 'brewery_name', 'style',
#        'nbr_ratings', 'nbr_reviews', 'avg', 'ba_score', 'bros_score', 'abv',
#        'avg_computed', 'zscore', 'nbr_matched_valid_ratings',
#        'avg_matched_valid_ratings'],
#       dtype='object')
# (280823, 15)
#         beer_id                         beer_name  brewery_id  \
# 241896   102949               South Pacific Brown       29682
# 141794   189139                      Black Saison       34426
# 237446   234651                     Paisan Porter       43242
# 78900    203010                     Apricot Wheat       30298
# 112334    93099                       Chico Suave          14
# 238801    19561                Anniversary Tripel         818
# 233136   291649                     Gaelforce IPA       48115
# 51242      9681           Diekirch Grande Réserve        2697
# 111982    45844  Samuel Adams Harvest Pumpkin Ale          35
# 23484    237741                     Blonde Saison       46250
#
#                                        brewery_name                   style  \
# 241896                 Kauai Island Brewery & Grill      American Brown Ale
# 141794                    Jailbreak Brewing Company  Saison / Farmhouse Ale
# 237446                  JD's Sports Bar and Brewery         American Porter
# 78900                     Roseville Brewing Company  Fruit / Vegetable Beer
# 112334                    Cambridge Brewing Company            American IPA
# 238801                     McKenzie Brewing Company                  Tripel
# 233136                  Drumconrath Brewing Company            American IPA
# 51242   Brasserie de Luxembourg Mousel -Diekirch SA     Munich Dunkel Lager
# 111982           Boston Beer Company (Samuel Adams)             Pumpkin Ale
# 23484                      Kettle River Brewing Co.  Saison / Farmhouse Ale
#
#         nbr_ratings  nbr_reviews   avg  ba_score  bros_score  abv  \
# 241896            9            1  3.64       NaN         NaN  3.8
# 141794            1            0  3.25       NaN         NaN  5.6
# 237446            1            0  3.04       NaN         NaN  5.0
# 78900             0            0   NaN       NaN         NaN  NaN
# 112334            4            2  4.13       NaN         NaN  4.8
# 238801            1            1  3.31       NaN         NaN  NaN
# 233136            1            0  3.77       NaN         NaN  6.2
# 51242             1            1  2.97       NaN         NaN  6.9
# 111982         2635          648  3.58      81.0        72.0  5.7
# 23484             0            0   NaN       NaN         NaN  3.9
#
#         avg_computed    zscore  nbr_matched_valid_ratings  \
# 241896      3.585556       NaN                          0
# 141794      3.250000       NaN                          0
# 237446      3.040000       NaN                          0
# 78900            NaN       NaN                          0
# 112334      4.175000       NaN                          0
# 238801      3.310000       NaN                          0
# 233136      3.770000 -0.515113                          0
# 51242       2.970000       NaN                          0
# 111982      3.469696       NaN                          0
# 23484            NaN       NaN                          0
#
#         avg_matched_valid_ratings
# 241896                        NaN
# 141794                        NaN
# 237446                        NaN
# 78900                         NaN
# 112334                        NaN
# 238801                        NaN
# 233136                        NaN
# 51242                         NaN
# 111982                        NaN
# 23484                         NaN

# %%
#out of exploration out of src
breweries = pd.read_csv('../../baseData/BeerAdvocate/breweries.csv')

print(breweries.shape)
breweries.drop_duplicates(inplace=True)
print(breweries.columns)
print(breweries.shape)
breweries.sample(10)
# Out:
# (16758, 4)
# Index(['id', 'location', 'name', 'nbr_beers'], dtype='object')
# (16758, 4)
#           id                   location  \
# 15735  13658            Canada, Ontario
# 15482   4384     United States, Montana
# 13177  44401    United States, Michigan
# 9612   47435  United States, New Jersey
# 4489   16829                    Germany
# 15617  14916             Canada, Quebec
# 14501    321                    Belgium
# 3556    7613                    Germany
# 3496    5860                    Germany
# 8776   35011  United States, California
#
#                                                    name  nbr_beers
# 15735  Draft Horse Brewery / Navan Feed Mill Restaurant          0
# 15482                             Lightning Boy Brewery          1
# 13177                     Kilkenny's Irish Public House          0
# 9612                                      Troon Brewing         30
# 4489                            Bayreuther Bierbrauerei         14
# 15617                           Les Brasseurs du Hameau         47
# 14501                              Brasserie d'Achouffe         20
# 3556                        Wittichenauer Stadtbrauerei          1
# 3496                        Brauerei Xaver Wasserburger          0
# 8776                                  Sundowner Brewery         32

# %%
#out of exploration out of src
users = pd.read_csv('../../baseData/BeerAdvocate/users.csv')

print(users.shape)
users.drop_duplicates(inplace=True)
print(users.columns)
print(users.shape)
users.sample(10)
# Out:
# (153704, 6)
# Index(['nbr_ratings', 'nbr_reviews', 'user_id', 'user_name', 'joined',
#        'location'],
#       dtype='object')
# (153704, 6)
#         nbr_ratings  nbr_reviews                   user_id         user_name  \
# 11460             4            0         crazybrody.706269        crazybrody
# 5261              9            2  wwwagainsttimeca.1149511  wwwagainsttimeca
# 22094           438            0             seaale.682156            SeaAle
# 57588             2            0            jake095.919394           jake095
# 88755             1            0     mountainmaniac.438398    MountainManiac
# 111826            3            1           jelpernw.408660          jelpernw
# 86106            15            0          sethberry.938950         Sethberry
# 33526             6            2         fivebyfive.793394        FiveByFive
# 94272             1            0    tagyoureit24824.919262   tagyoureit24824
# 58931             1            0     thefearedbeard.707199    TheFearedBeard
#
#               joined                 location
# 11460   1.354705e+09   United States, Indiana
# 5261    1.464430e+09                   Canada
# 22094   1.340532e+09    United States, Oregon
# 57588   1.420283e+09                      NaN
# 88755   1.268651e+09  United States, Colorado
# 111826  1.261825e+09  United States, New York
# 86106   1.423048e+09                      NaN
# 33526   1.397038e+09                   Canada
# 94272   1.420283e+09                      NaN
# 58931   1.355224e+09                      NaN

# %%
#there are 151 million lines of text... thats a lot
def parse_ratings_file(file_path, limit):
    data = []
    current_block = []
    i = 0

    with open(file_path, 'r') as file:  
        for line in file:
            i += 1
            
            if i%1_000_000 == 0: print('line x million: ', i/1_000_000)
            if i > limit :
                print('Saved first ' + str(limit/1_000_000) + ' million lines')
                break
            
            line = line.strip()  # Remove leading/trailing whitespace
            
            if not line: #if empty line, '' treated as false
                data.append(current_block)
                current_block = []
                continue #next iteration of loop
            
            if ': ' in line:  
                key, value = line.split(': ', 1)  # Split by the first occurrence of ': '
                current_block.append(value)
            

    # Convert the list of lists to a DataFrame
    return pd.DataFrame(data)


ratings_df = parse_ratings_file('../../baseData/BeerAdvocate/ratings.txt', limit = 10_000_000)

#since our txt file is in a predicatble format we can make things easy on ourselves
new_column_names = [
    'beer_name',
    'beer_id',
    'brewery_name',  
    'brewery_id',    
    'style',         
    'abv',           
    'date',          
    'user_name',     
    'user_id',       
    'appearance',    
    'aroma',         
    'palate',        
    'taste',         
    'overall',       
    'rating',        
    'text',
    'review'
]

ratings_df.columns =  new_column_names
# Display the first few rows of the DataFrame
ratings_df.sample(10)
# Out:
# line x million:  1.0
# line x million:  2.0
# line x million:  3.0
# line x million:  4.0
# line x million:  5.0
# line x million:  6.0
# line x million:  7.0
# line x million:  8.0
# line x million:  9.0
# line x million:  10.0
# Saved first 10.0 million lines
#                                             beer_name beer_id  \
# 158629                           Original Flag Porter   14563
# 16077                                      Blackfriar   14518
# 19107                                 McEwan's Export    4587
# 91406          Samuel Smith's The Famous Taddy Porter     572
# 138492                         Fuller's London Porter     221
# 198723                            Iron Maiden Trooper   96511
# 453400                           Side Launch Colossus  148873
# 388621                              Old Yale Pale Ale   13670
# 396844  Flying Monkeys Netherworld Cascadian Dark Ale   53832
# 210902                          Dos Equis Amber Lager     171
#
#                                          brewery_name brewery_id  \
# 158629                            Darwin Brewery Ltd.        935
# 16077                   Inveralmond Brewery Ltd., The       1108
# 19107                  The Caledonian Brewing Company        188
# 91406            Samuel Smith Old Brewery (Tadcaster)        113
# 138492                      Fuller Smith & Turner PLC         71
# 198723                       Robinsons Family Brewers      23394
# 453400                    Side Launch Brewing Company      34726
# 388621                           Old Yale Brewing Co.       3711
# 396844                   Flying Monkeys Craft Brewery      10796
# 210902  Cervecería Cuauhtémoc Moctezuma, S.A. de C.V.         57
#
#                                       style  abv        date        user_name  \
# 158629                       English Porter  5.0  1107169200           rkhaze
# 16077                          Scottish Ale  7.0  1248084000           popery
# 19107                          Scottish Ale  4.5  1092218400       cypressbob
# 91406                        English Porter  5.0  1333274400              jk3
# 138492                       English Porter  5.4  1416308400    Arriskuwonder
# 198723  Extra Special / Strong Bitter (ESB)  4.7  1398247200  BrazilianAussie
# 453400                         Dunkelweizen  8.0  1435658400    TheSevenDuffs
# 388621              American Pale Ale (APA)  5.0  1459418400        GlendonTT
# 396844                   American Black Ale  6.0  1386932400        Noxious26
# 210902                         Vienna Lager  4.7  1339063200        hardcor33
#
#                        user_id appearance aroma palate taste overall rating  \
# 158629             rkhaze.2969        4.0   4.5    4.0   4.0     4.0   4.12
# 16077            popery.196587        4.0   3.5    4.0   4.0     4.0   3.88
# 19107          cypressbob.3708        3.5   4.0    4.0   3.0     4.0   3.57
# 91406               jk3.638051        nan   nan    nan   nan     nan   4.00
# 138492    arriskuwonder.793725        nan   nan    nan   nan     nan   4.25
# 198723  brazilianaussie.660776        nan   nan    nan   nan     nan   3.25
# 453400    thesevenduffs.417825       3.75  3.75   3.75  3.75    3.75   3.75
# 388621        glendontt.810901       3.75   3.5   3.75   3.5     3.5   3.54
# 396844         noxious26.22115        4.5  4.25    3.0  3.75    3.75   3.84
# 210902        hardcor33.534622        nan   nan    nan   nan     nan   3.00
#
#                                                      text review
# 158629  Pours out a light mahogany color with a big cr...   True
# 16077   Dark amber brown liquid decent lacing. The nos...   True
# 19107   Standard can, redPours with a brown body, slig...   True
# 91406                                                 nan  False
# 138492                                                nan  False
# 198723                                                nan  False
# 453400                                                nan  False
# 388621                                                nan  False
# 396844  355ml brown bottle poured in a pint glass. Pur...   True
# 210902                                                nan  False

# %%
#reviews.txt is ratings.txt but only where there are reviews, (review: True)
#there are 45 million lines of text... thats a lot
def parse_ratings_file(file_path, limit):
    data = []
    current_block = []
    i = 0

    with open(file_path, 'r') as file:  
        for line in file:
            i += 1
            
            if i%1_000_000 == 0: print('line x million: ', i/1_000_000)
            if i > limit :
                print('Saved first ' + str(limit/1_000_000) + ' million lines')
                break
            
            line = line.strip()  # Remove leading/trailing whitespace
            
            if not line: #if empty line, '' treated as false
                data.append(current_block)
                current_block = []
                continue #next iteration of loop
            
            if ': ' in line:  
                key, value = line.split(': ', 1)  # Split by the first occurrence of ': '
                current_block.append(value)
            

    # Convert the list of lists to a DataFrame
    return pd.DataFrame(data)


ratings_df = parse_ratings_file('../../baseData/BeerAdvocate/reviews.txt', limit = 10_000_000)

#since our txt file is in a predicatble format we can make things easy on ourselves
new_column_names = [
    'beer_name',
    'beer_id',
    'brewery_name',  
    'brewery_id',    
    'style',         
    'abv',           
    'date',          
    'user_name',     
    'user_id',       
    'appearance',    
    'aroma',         
    'palate',        
    'taste',         
    'overall',       
    'rating',        
    'text',
]

ratings_df.columns =  new_column_names
# Display the first few rows of the DataFrame
ratings_df.sample(10)
# Out:
# line x million:  1.0
# line x million:  2.0
# line x million:  3.0
# line x million:  4.0
# line x million:  5.0
# line x million:  6.0
# line x million:  7.0
# line x million:  8.0
# line x million:  9.0
# line x million:  10.0
# Saved first 10.0 million lines
#                                      beer_name beer_id  \
# 252436                            DAB Original    2831
# 469894                              Native Ale    6663
# 462230                              Summarillo  176189
# 248343  Schneider Weisse Tap 6 Unser Aventinus     224
# 230404                               Black Tie   59285
# 440145                    Leinie's Amber Light    3776
# 33720                 Samuel Smith's India Ale     573
# 249474   Schneider Weisse Tap 7 Unser Original    3280
# 416459                        Guinness Draught     754
# 1993               Ola Dubh Special Reserve 12   41037
#
#                                      brewery_name brewery_id  \
# 252436           Dortmunder Actien Brauerei / DAB        726
# 469894                 New Glarus Brewing Company        590
# 462230                 Central Waters Brewing Co.        652
# 248343  Weisses Bräuhaus G. Schneider & Sohn GmbH         72
# 230404                              Mikkeller ApS      13307
# 440145          Jacob Leinenkugel Brewing Company        710
# 33720        Samuel Smith Old Brewery (Tadcaster)        113
# 249474  Weisses Bräuhaus G. Schneider & Sohn GmbH         72
# 416459                              Guinness Ltd.        209
# 1993                     Harviestoun Brewery Ltd.        323
#
#                                    style   abv        date      user_name  \
# 252436         Dortmunder / Export Lager   5.0  1103281200          mynie
# 469894                 English Brown Ale   5.0  1118570400       Sixpoint
# 462230               American Pale Lager   5.2  1438596000          jzlyo
# 248343                        Weizenbock   8.2  1190800800    jtrockchalk
# 230404  American Double / Imperial Stout  11.5  1332756000     BlastBeats
# 440145                       Light Lager   nan  1122372000      bditty187
# 33720       English India Pale Ale (IPA)   5.0  1129975200     Holyterror
# 249474                        Hefeweizen   5.4  1214647200  Brianmerrilyn
# 416459                   Irish Dry Stout   4.2  1290164400    BeerdedEric
# 1993                             Old Ale   8.0  1372932000        dwren89
#
#                      user_id appearance aroma palate taste overall rating  \
# 252436            mynie.6910        3.0   3.5    3.5   3.0     2.0   2.97
# 469894         sixpoint.7531        3.5   4.0    3.5   4.0     4.5   4.02
# 462230          jzlyo.663004       3.75   4.0    4.0   4.0     4.0   3.99
# 248343     jtrockchalk.99303        4.0   4.0    4.0   4.5     4.0   4.20
# 230404     blastbeats.584434        4.0   5.0    4.5   4.0     4.0   4.29
# 440145         bditty187.531        4.0   3.0    3.0   3.5     3.0   3.26
# 33720        holyterror.5015        3.5   3.5    3.5   4.0     4.0   3.80
# 249474  brianmerrilyn.136551        4.0   4.0    4.0   4.5     4.0   4.20
# 416459    beerdederic.510922        4.0   2.5    4.0   3.5     3.5   3.34
# 1993          dwren89.648710        4.5   4.0    4.5  4.75     4.5   4.48
#
#                                                      text
# 252436  &quot;The Beer of World Fame.&quot;Okay.Pours ...
# 469894  Is &quot;SLAMMABLE&quot; a word? It is if you'...
# 462230  Aroma is pine, tropical fruit and mildly grain...
# 248343  First review.A - Dark brown like a grade B map...
# 230404  Poured this bottle of Black Tie into my Mikkel...
# 440145  Golden-amber in hue, a steady stream of animat...
# 33720   SS's India Ale poured a medium copper with a s...
# 249474  16.9 oz. poured into mini heffe glass...many t...
# 416459  Poured halfway into a mug from a can and poure...
# 1993    Appearance: Pitch black, tan head, but disinte...
