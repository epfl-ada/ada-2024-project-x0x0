# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
import os
print(os.getcwd())
# Out:
# /home/belgie/Documents/EPFL/Masters/MA1/ADA/Project/ADA-X0x0/P2/ada-2024-project-x0x0/src/exploration

# %% [markdown]
# ## Looking at BeerAdvocate

# %%
#out of exploration out of src
beers = pd.read_csv('../../baseData/BeerAdvocate/beers.csv')

print(beers.shape)
beers.drop_duplicates(inplace=True)
print(beers.columns)
print(beers.shape)
beers.sample(10)
# Out:
# (280823, 15)
# Index(['beer_id', 'beer_name', 'brewery_id', 'brewery_name', 'style',
#        'nbr_ratings', 'nbr_reviews', 'avg', 'ba_score', 'bros_score', 'abv',
#        'avg_computed', 'zscore', 'nbr_matched_valid_ratings',
#        'avg_matched_valid_ratings'],
#       dtype='object')
# (280823, 15)
#         beer_id                         beer_name  brewery_id  \
# 241896   102949               South Pacific Brown       29682
# 141794   189139                      Black Saison       34426
# 237446   234651                     Paisan Porter       43242
# 78900    203010                     Apricot Wheat       30298
# 112334    93099                       Chico Suave          14
# 238801    19561                Anniversary Tripel         818
# 233136   291649                     Gaelforce IPA       48115
# 51242      9681           Diekirch Grande Réserve        2697
# 111982    45844  Samuel Adams Harvest Pumpkin Ale          35
# 23484    237741                     Blonde Saison       46250
#
#                                        brewery_name                   style  \
# 241896                 Kauai Island Brewery & Grill      American Brown Ale
# 141794                    Jailbreak Brewing Company  Saison / Farmhouse Ale
# 237446                  JD's Sports Bar and Brewery         American Porter
# 78900                     Roseville Brewing Company  Fruit / Vegetable Beer
# 112334                    Cambridge Brewing Company            American IPA
# 238801                     McKenzie Brewing Company                  Tripel
# 233136                  Drumconrath Brewing Company            American IPA
# 51242   Brasserie de Luxembourg Mousel -Diekirch SA     Munich Dunkel Lager
# 111982           Boston Beer Company (Samuel Adams)             Pumpkin Ale
# 23484                      Kettle River Brewing Co.  Saison / Farmhouse Ale
#
#         nbr_ratings  nbr_reviews   avg  ba_score  bros_score  abv  \
# 241896            9            1  3.64       NaN         NaN  3.8
# 141794            1            0  3.25       NaN         NaN  5.6
# 237446            1            0  3.04       NaN         NaN  5.0
# 78900             0            0   NaN       NaN         NaN  NaN
# 112334            4            2  4.13       NaN         NaN  4.8
# 238801            1            1  3.31       NaN         NaN  NaN
# 233136            1            0  3.77       NaN         NaN  6.2
# 51242             1            1  2.97       NaN         NaN  6.9
# 111982         2635          648  3.58      81.0        72.0  5.7
# 23484             0            0   NaN       NaN         NaN  3.9
#
#         avg_computed    zscore  nbr_matched_valid_ratings  \
# 241896      3.585556       NaN                          0
# 141794      3.250000       NaN                          0
# 237446      3.040000       NaN                          0
# 78900            NaN       NaN                          0
# 112334      4.175000       NaN                          0
# 238801      3.310000       NaN                          0
# 233136      3.770000 -0.515113                          0
# 51242       2.970000       NaN                          0
# 111982      3.469696       NaN                          0
# 23484            NaN       NaN                          0
#
#         avg_matched_valid_ratings
# 241896                        NaN
# 141794                        NaN
# 237446                        NaN
# 78900                         NaN
# 112334                        NaN
# 238801                        NaN
# 233136                        NaN
# 51242                         NaN
# 111982                        NaN
# 23484                         NaN

# %%
#out of exploration out of src
breweries = pd.read_csv('../../baseData/BeerAdvocate/breweries.csv')

print(breweries.shape)
breweries.drop_duplicates(inplace=True)
print(breweries.columns)
print(breweries.shape)
breweries.sample(10)
# Out:
# (16758, 4)
# Index(['id', 'location', 'name', 'nbr_beers'], dtype='object')
# (16758, 4)
#           id                   location  \
# 15735  13658            Canada, Ontario
# 15482   4384     United States, Montana
# 13177  44401    United States, Michigan
# 9612   47435  United States, New Jersey
# 4489   16829                    Germany
# 15617  14916             Canada, Quebec
# 14501    321                    Belgium
# 3556    7613                    Germany
# 3496    5860                    Germany
# 8776   35011  United States, California
#
#                                                    name  nbr_beers
# 15735  Draft Horse Brewery / Navan Feed Mill Restaurant          0
# 15482                             Lightning Boy Brewery          1
# 13177                     Kilkenny's Irish Public House          0
# 9612                                      Troon Brewing         30
# 4489                            Bayreuther Bierbrauerei         14
# 15617                           Les Brasseurs du Hameau         47
# 14501                              Brasserie d'Achouffe         20
# 3556                        Wittichenauer Stadtbrauerei          1
# 3496                        Brauerei Xaver Wasserburger          0
# 8776                                  Sundowner Brewery         32

# %%
#out of exploration out of src
users = pd.read_csv('../../baseData/BeerAdvocate/users.csv')

print(users.shape)
users.drop_duplicates(inplace=True)
print(users.columns)
print(users.shape)
users.sample(10)
# Out:
# (153704, 6)
# Index(['nbr_ratings', 'nbr_reviews', 'user_id', 'user_name', 'joined',
#        'location'],
#       dtype='object')
# (153704, 6)
#         nbr_ratings  nbr_reviews                   user_id         user_name  \
# 11460             4            0         crazybrody.706269        crazybrody
# 5261              9            2  wwwagainsttimeca.1149511  wwwagainsttimeca
# 22094           438            0             seaale.682156            SeaAle
# 57588             2            0            jake095.919394           jake095
# 88755             1            0     mountainmaniac.438398    MountainManiac
# 111826            3            1           jelpernw.408660          jelpernw
# 86106            15            0          sethberry.938950         Sethberry
# 33526             6            2         fivebyfive.793394        FiveByFive
# 94272             1            0    tagyoureit24824.919262   tagyoureit24824
# 58931             1            0     thefearedbeard.707199    TheFearedBeard
#
#               joined                 location
# 11460   1.354705e+09   United States, Indiana
# 5261    1.464430e+09                   Canada
# 22094   1.340532e+09    United States, Oregon
# 57588   1.420283e+09                      NaN
# 88755   1.268651e+09  United States, Colorado
# 111826  1.261825e+09  United States, New York
# 86106   1.423048e+09                      NaN
# 33526   1.397038e+09                   Canada
# 94272   1.420283e+09                      NaN
# 58931   1.355224e+09                      NaN

# %%
#there are 151 million lines of text... thats a lot
def parse_ratings_file(file_path, limit):
    data = []
    current_block = []
    i = 0

    with open(file_path, 'r') as file:  
        for line in file:
            i += 1
            
            # if i%1_000_000 == 0: print('line x million: ', i/1_000_000)
            # if i > limit :
            #     print('Saved first ' + str(limit/1_000_000) + ' million lines')
            #     break
            
            line = line.strip()  # Remove leading/trailing whitespace
            
            if not line: #if empty line, '' treated as false
                data.append(current_block)
                current_block = []
                continue #next iteration of loop
            
            if ': ' in line:  
                key, value = line.split(': ', 1)  # Split by the first occurrence of ': '
                current_block.append(value)
            

    # Convert the list of lists to a DataFrame
    return pd.DataFrame(data)


ratings_df = parse_ratings_file('../../Thomas/baseData/RateBeer/ratings.txt', limit = None)

#since our txt file is in a predicatble format we can make things easy on ourselves
new_column_names = [
    'beer_name',
    'beer_id',
    'brewery_name',  
    'brewery_id',    
    'style',         
    'abv',           
    'date',          
    'user_name',     
    'user_id',       
    'appearance',    
    'aroma',         
    'palate',        
    'taste',         
    'overall',       
    'rating',        
    'text'
]

ratings_df.columns =  new_column_names
# Display the first few rows of the DataFrame
ratings_df.sample(10)
# Out:
#                                     beer_name beer_id  \
# 604911                   Beer Here Rocketfuel  251896
# 937834    Duckstein Braumeister Edition No 06  344505
# 6234480                 Bartrams Cherry Stout   39627
# 3321025                   Smog City Hive Five  230064
# 4812836  Bold City Dukes Cold Nose Brown Ale   98745
# 66814    Collider Chornyj Santa (Black Santa)  394722
# 6769550   Chimay Dorée / Spéciale du Potaupré   14228
# 223365                  Unibroue Édition 2004   28540
# 4784324      Midnight Sun Cohoho Imperial IPA   17442
# 2608772         Furthermore Fatty Boombalatty   71126
#
#                                               brewery_name brewery_id  \
# 604911                                           Beer Here      10032
# 937834   Mecklenburgische Brauerei Lübz &#40;Carlsberg&...       2513
# 6234480                                           Bartrams       2118
# 3321025                                  Smog City Brewing      13523
# 4812836                                  Bold City Brewery       9942
# 66814                                     Collider Brewery      25975
# 6769550                                             Chimay         12
# 223365                          Unibroue &#40;Sapporo&#41;        180
# 4784324                       Midnight Sun Brewing Company        424
# 2608772                                        Furthermore       6951
#
#                         style   abv        date        user_name user_id  \
# 604911   India Pale Ale (IPA)   6.0  1417863600        VastActiv  219974
# 937834               Pilsener   4.9  1443002400  Kristall-KÃ¶nig  128589
# 6234480                 Stout   4.8  1097056800             Joeh    2876
# 3321025             Amber Ale   7.0  1446634800          thome50   11173
# 4812836             Brown Ale   7.0  1418814000         Tmoney99   11116
# 66814         Imperial Porter   8.4  1455706800             zvsn  260049
# 6769550           Belgian Ale   4.8  1388228400          poech73  264420
# 223365     Belgian Strong Ale  10.5  1079694000        jercraigs    8067
# 4784324          Imperial IPA   8.0  1089626400           hopdog   12252
# 2608772    Belgian Strong Ale   7.2  1417172400       akoeninger  160031
#
#         appearance aroma palate taste overall rating  \
# 604911           3     7      3     7      13   3.30
# 937834           3     7      3     7      11   3.10
# 6234480          3     6      4     6      14   3.30
# 3321025          3     6      3     5      14   3.10
# 4812836          4     7      4     6      14   3.50
# 66814            3     6      3     6      12   3.00
# 6769550          4     7      4     7      15   3.70
# 223365           4     7      4     7      15   3.70
# 4784324          4     8      4     8      17   4.10
# 2608772          3     7      3     7      14   3.40
#
#                                                       text
# 604911   Bottle 0.33l at Pikkulintu, Helsinki. Colour i...
# 937834   Floral-wÃ¼rziger Geruch. Startet sÃ¼Ãlich mit...
# 6234480  Cask Conditioned at the Bedford Beer Festival ...
# 3321025  Bottle at the Libertine November bottle share....
# 4812836  Draft. Poured clear brown color with an averag...
# 66814    Bottle sample at a tasting. Thanks Stas. Brown...
# 6769550  BiÃ¨re blonde trouble Ã  la robe trouble et au...
# 223365   Re-rate March 18 2004. Didn't enjoy this as mu...
# 4784324  Poured a dark amber/orange in color with a hug...
# 2608772  Amber color. Aroma of coriander, yeasty fruit,...

# %%
ratings_df.to_csv('../../Thomas/baseData/RateBeer/ratings.csv', index=False)

# %%
#reviews.txt is ratings.txt but only where there are reviews, (review: True)
#there are 45 million lines of text... thats a lot
def parse_ratings_file(file_path, limit):
    data = []
    current_block = []
    i = 0

    with open(file_path, 'r') as file:  
        for line in file:
            i += 1
            
            # if i%1_000_000 == 0: print('line x million: ', i/1_000_000)
            # if i > limit :
            #     print('Saved first ' + str(limit/1_000_000) + ' million lines')
            #     break
            
            line = line.strip()  # Remove leading/trailing whitespace
            
            if not line: #if empty line, '' treated as false
                data.append(current_block)
                current_block = []
                continue #next iteration of loop
            
            if ': ' in line:  
                key, value = line.split(': ', 1)  # Split by the first occurrence of ': '
                current_block.append(value)
            

    # Convert the list of lists to a DataFrame
    return pd.DataFrame(data)


reviews_df = parse_ratings_file('../../Thomas/baseData/RateBeer/reviews.txt', limit = None)

#since our txt file is in a predicatble format we can make things easy on ourselves
new_column_names = [
    'beer_name',
    'beer_id',
    'brewery_name',  
    'brewery_id',    
    'style',         
    'abv',           
    'date',          
    'user_name',     
    'user_id',       
    'appearance',    
    'aroma',         
    'palate',        
    'taste',         
    'overall',       
    'rating',        
    'text'
]

reviews_df.columns =  new_column_names
# Display the first few rows of the DataFrame
reviews_df.sample(10)
# Out:
#                                            beer_name beer_id  \
# 2164397                      Three Hearts 50 år 3.5%   50771
# 6662317                      Duysters Loterbol Bruin   22337
# 3903658  Fort Collins Kidd Black Lager (Schwarzbier)   30736
# 5886321                                 Crate I.P.A.  179853
# 1177510                           Pyraser Kellerbier   68754
# 9338                       Lucky Beer (Lucky Buddha)   51355
# 929021    Lidl Perlenbacher Schwarzbier / Black Beer  289391
# 5511531                   Two Brothers Cane and Ebel   59141
# 556963                            Ebrius Brewing IPA  155546
# 5900835              Fullers Imperial Stout (10.7%)  226113
#
#                                  brewery_name brewery_id  \
# 2164397                    Krönleins Bryggeri        191
# 6662317     Brouwerij Loterbol (was Duysters)       1958
# 3903658                  Fort Collins Brewery       3891
# 5886321                         Crate Brewery      14881
# 1177510                  Pyraser Landbrauerei       4623
# 9338     Cheerday Hangzhou Qiandaohu Beer Co.      11483
# 929021               Mauritius Privatbrauerei       1851
# 5511531          Two Brothers Brewing Company        507
# 556963                         Ebrius Brewing      13678
# 5900835                              Fullers         55
#
#                            style   abv        date   user_name user_id  \
# 2164397               Pale Lager   3.5  1207821600  KnutAlbert   26960
# 6662317       Belgian Strong Ale   8.0  1338890400    tderoeck  101220
# 3903658              Schwarzbier   4.5  1240826400       LtDan   74534
# 5886321     India Pale Ale (IPA)   5.8  1395140400      rodbod  294971
# 1177510  Zwickel/Keller/Landbier   4.8  1353322800    3fourths    6533
# 9338                  Pale Lager   4.8  1334916000  anders8000  147471
# 929021               Schwarzbier   4.9  1486724400     Calisky  106177
# 5511531          Specialty Grain   7.0  1207389600      Juelze   20180
# 556963      India Pale Ale (IPA)   4.9  1329476400   dreadnord  146208
# 5900835           Imperial Stout  10.7  1427540400  The_Osprey  249130
#
#         appearance aroma palate taste overall rating  \
# 2164397          3     4      2     5       9   2.30
# 6662317          4     5      4     8      15   3.60
# 3903658          3     5      4     8      14   3.40
# 5886321          4     7      4     8      16   3.90
# 1177510          4     7      3     6      13   3.30
# 9338             4     3      3     5      12   2.70
# 929021           3     6      3     5      11   2.80
# 5511531          4     7      3     7      17   3.80
# 556963           4     8      4     8      16   4.00
# 5900835          4     7      4     7      16   3.80
#
#                                                       text
# 2164397  Can from a Svinesund supermarket.Decent attemp...
# 6662317  29/V/2012 - 33cl bottle from Geers (Oostakker)...
# 3903658  Appearance:  Pours a midnight amber letting al...
# 5886321  Bottle from the Good Spirits Co, Glasgow. Ambe...
# 1177510  steinkrug at the new Huttân, Nuremberg.spicy...
# 9338     Light aromas of hops with nuances of honey & m...
# 929021   Couleur brune sombre, trÃ¨s lÃ©gÃ¨re mousse. N...
# 5511531  Pours a dark amber color with thick white foam...
# 556963   Pours darker yellow with a big white head. Nos...
# 5900835  Mar 2015 - 500ml, boxed, 10.7%, 2013 vintage. ...

# %%
reviews_df.to_csv('../../Thomas/baseData/RateBeer/reviews.csv', index=False)
